# %%
import pandas as pd

df = pd.read_excel("pda_especies_ameacadas.xlsx")
df
# Out:
#       sq_ficha   sq_taxon                     Nome Cientifico  \
# 0      24266.0  1063250.0                   Aburria jacutinga
# 1      30964.0  2025106.0             Aceratobasis cornicauda
# 2      30966.0  2025108.0                 Aceratobasis mourei
# 3      12840.0  2028135.0              Acherontides eleonorae
# 4      24268.0     8285.0               Acrobatornis fonsecai
# ...        ...        ...                                 ...
# 1168       NaN  1019956.0                     Mobula japanica
# 1169       NaN  2026052.0  Ozotoceros bezoarticus leucogaster
# 1170       NaN     9136.0                     Pyrrhura lepida
# 1171       NaN  2026038.0              Pyrrhura lepida lepida
# 1172       NaN     6891.0                      Tijuca condita
#
#                                          Nome Comum  \
# 0                                         jacutinga
# 1                                               NaN
# 2                                               NaN
# ...

# %%
for especie in df["Nome Cientifico"]:
    if "Bothrops" in especie:
        print(especie)
ilhoa = df[df["Nome Cientifico"] == "Bothrops insularis"]
# Out:
# Bothrops alcatraz
# Bothrops insularis
# Bothrops muriciensis
# Bothrops otavioi
# Bothrops pirajai

# %%
ilhoa
# Out:
#      sq_ficha   sq_taxon     Nome Cientifico      Nome Comum Grupo Taxonômico  \
# 170   25544.0  1255190.0  Bothrops insularis  jararaca-ilhôa          Répteis
#
#               Categoria de Risco  \
# 170  Criticamente em Perigo (CR)
#
#                   Unidades de Conservação onde ocorrem   Código CNUC
# 170  Área de Relevante Interesse Ecológico Ilha Que...  0000.00.0037
