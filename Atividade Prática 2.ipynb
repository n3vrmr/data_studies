# %% [markdown]
# # Atividade Prática 2
#
# Nessa atividade, vamos explorar conjuntos de dados distintos e será seu trabalho descrever os conjuntos dados.

# %%
import pandas as pd

dados1 = pd.read_csv('dados1.csv')
dados2 = pd.read_csv('dados2.csv')
dados3 = pd.read_csv('dados3.csv')

# %%
# Realize uma análise descritiva dos dados
# Deve conter as informações básicas do conjunto
# Número de elementos
# Nome e número de observações das colunas
# Estatística descritiva: média, desvio-padrão, correlação
dados1
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
dados1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
dados1.mean(numeric_only=True)
# Out:
# Unnamed: 0    26970.500000
# carat             0.797940
# depth            61.749405
# table            57.457184
# price          3932.799722
# x                 5.731157
# y                 5.734526
# z                 3.538734
# dtype: float64

# %%
dados1.carat.describe()
# Out:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64

# %%
dados1[dados1["carat"] > 5]
# Out:
#        Unnamed: 0  carat   cut color clarity  depth  table  price      x  \
# 27415       27416   5.01  Fair     J      I1   65.5   59.0  18018  10.74
#
#            y     z
# 27415  10.54  6.98

# %%
dados1.std(numeric_only=True)
# Out:
# Unnamed: 0    15571.281097
# carat             0.474011
# depth             1.432621
# table             2.234491
# price          3989.439738
# x                 1.121761
# y                 1.142135
# z                 0.705699
# dtype: float64

# %%
dados1.corr()
# Out:
#             Unnamed: 0     carat     depth     table     price         x  \
# Unnamed: 0    1.000000 -0.377983 -0.034800 -0.100830 -0.306873 -0.405440
# carat        -0.377983  1.000000  0.028224  0.181618  0.921591  0.975094
# depth        -0.034800  0.028224  1.000000 -0.295779 -0.010647 -0.025289
# table        -0.100830  0.181618 -0.295779  1.000000  0.127134  0.195344
# price        -0.306873  0.921591 -0.010647  0.127134  1.000000  0.884435
# x            -0.405440  0.975094 -0.025289  0.195344  0.884435  1.000000
# y            -0.395843  0.951722 -0.029341  0.183760  0.865421  0.974701
# z            -0.399208  0.953387  0.094924  0.150929  0.861249  0.970772
#
#                    y         z
# Unnamed: 0 -0.395843 -0.399208
# carat       0.951722  0.953387
# depth      -0.029341  0.094924
# table       0.183760  0.150929
# price       0.865421  0.861249
# x           0.974701  0.970772
# y           1.000000  0.952006
# z           0.952006  1.000000

# %%
# Realize uma análise descritiva dos dados
# Deve conter as informações básicas do conjunto
# Número de elementos
# Nome e número de observações das colunas
# Estatística descritiva: média, desvio-padrão, correlação
dados2
# Out:
#            long        lat unique_squirrel_id hectare shift      date  \
# 0    -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1    -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2    -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3    -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4    -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
# ...         ...        ...                ...     ...   ...       ...
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       hectare_squirrel_number       age primary_fur_color  \
# 0                           3       NaN               NaN
# ...

# %%
dados2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 36 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   long                                        3023 non-null   float64
#  1   lat                                         3023 non-null   float64
#  2   unique_squirrel_id                          3023 non-null   object
#  3   hectare                                     3023 non-null   object
#  4   shift                                       3023 non-null   object
#  5   date                                        3023 non-null   int64
#  6   hectare_squirrel_number                     3023 non-null   int64
#  7   age                                         2902 non-null   object
#  8   primary_fur_color                           2968 non-null   object
#  9   highlight_fur_color                         1937 non-null   object
# ...

# %%
dados2.mean(numeric_only=True)
# Out:
# long                      -7.396718e+01
# lat                        4.078085e+01
# date                       1.011949e+07
# hectare_squirrel_number    4.123718e+00
# running                    2.414820e-01
# chasing                    9.229242e-02
# climbing                   2.176646e-01
# eating                     2.514059e-01
# foraging                   4.746940e-01
# kuks                       3.374132e-02
# quaas                      1.653986e-02
# moans                      9.923917e-04
# tail_flags                 5.127357e-02
# tail_twitches              1.435660e-01
# approaches                 5.888191e-02
# indifferent                4.809792e-01
# runs_from                  2.242805e-01
# zip_codes                  1.182822e+04
# community_districts        1.899603e+01
# borough_boundaries         4.000000e+00
# city_council_districts     1.907046e+01
# police_precincts           1.300463e+01
# dtype: float64

# %%
dados2.std(numeric_only=True)
# Out:
# long                           0.007726
# lat                            0.010285
# date                       42466.714959
# hectare_squirrel_number        3.096492
# running                        0.428053
# chasing                        0.289486
# climbing                       0.412726
# eating                         0.433893
# foraging                       0.499442
# kuks                           0.180592
# quaas                          0.127560
# moans                          0.031492
# tail_flags                     0.220592
# tail_twitches                  0.350707
# approaches                     0.235442
# indifferent                    0.499721
# runs_from                      0.417177
# zip_codes                    995.983782
# community_districts            0.234339
# borough_boundaries             0.000000
# city_council_districts         1.352253
# police_precincts               0.224224
# dtype: float64

# %%
dados2.corr()
# Out:
#                              long       lat      date  \
# long                     1.000000  0.906838  0.104391
# lat                      0.906838  1.000000  0.161824
# date                     0.104391  0.161824  1.000000
# hectare_squirrel_number -0.131927 -0.121656 -0.045330
# running                  0.034092  0.041225  0.037451
# chasing                 -0.037457 -0.015951  0.024388
# climbing                 0.011311  0.005565 -0.070891
# eating                  -0.053743 -0.056371 -0.016823
# foraging                -0.006438 -0.005280  0.013283
# kuks                     0.057685  0.063737  0.024082
# quaas                    0.057433  0.059990  0.018114
# moans                    0.027252  0.022720  0.029096
# tail_flags               0.003152  0.002229 -0.034538
# tail_twitches           -0.008117 -0.006876 -0.015369
# approaches              -0.038302 -0.038296  0.025829
# indifferent             -0.048323 -0.075501 -0.031506
# ...

# %%
# Realize uma análise descritiva dos dados
# Deve conter as informações básicas do conjunto
# Número de elementos
# Nome e número de observações das colunas
# Estatística descritiva: média, desvio-padrão, correlação
dados3
# Out:
#                         Arc  Start onChapter  TotalChapters  TotalPages  \
# 0          Romance Dawn Arc                1              7         178
# 1           Orange Town Arc                8             14         273
# 2         Syrup Village Arc               22             20         396
# 3               Baratie Arc               42             27         514
# 4           Arlong Park Arc               69             27         514
# 5      Buggy Side Story Arc                0              0           0
# 6             Loguetown Arc               96              5         100
# 7        Warship Island Arc                0              0           0
# 8      Reverse Mountain Arc              101              5          96
# 9          Whiskey Peak Arc              106              9         169
# 10    Koby and Helmeppo Arc                0              0           0
# 11        Little Garden Arc              115             15         288
# ...

# %%
dados3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Arc                   51 non-null     object
#  1   Start onChapter       51 non-null     int64
#  2   TotalChapters         51 non-null     int64
#  3   TotalPages            51 non-null     int64
#  4   Manga%                51 non-null     object
#  5   Start onEpisode       51 non-null     int64
#  6   TotalEpisodes         51 non-null     int64
#  7   TotalMinutes(avg 24)  51 non-null     int64
#  8   Anime%                51 non-null     object
# dtypes: int64(6), object(3)
# memory usage: 3.7+ KB

# %%
dados3.mean(numeric_only=True)
# Out:
# Start onChapter         268.823529
# TotalChapters            20.705882
# TotalPages              381.490196
# Start onEpisode         354.745098
# TotalEpisodes            20.156863
# TotalMinutes(avg 24)    483.764706
# dtype: float64

# %%
dados3.std(numeric_only=True)
# Out:
# Start onChapter         317.019287
# TotalChapters            26.133728
# TotalPages              471.266268
# Start onEpisode         291.209742
# TotalEpisodes            24.345326
# TotalMinutes(avg 24)    584.287826
# dtype: float64

# %%
dados3.corr()
# Out:
#                       Start onChapter  TotalChapters  TotalPages  \
# Start onChapter              1.000000       0.595637    0.575794
# TotalChapters                0.595637       1.000000    0.998524
# TotalPages                   0.575794       0.998524    1.000000
# Start onEpisode              0.648648       0.236850    0.204692
# TotalEpisodes                0.684749       0.929732    0.918775
# TotalMinutes(avg 24)         0.684749       0.929732    0.918775
#
#                       Start onEpisode  TotalEpisodes  TotalMinutes(avg 24)
# Start onChapter              0.648648       0.684749              0.684749
# TotalChapters                0.236850       0.929732              0.929732
# TotalPages                   0.204692       0.918775              0.918775
# Start onEpisode              1.000000       0.393252              0.393252
# TotalEpisodes                0.393252       1.000000              1.000000
# ...

# %%
# O que cada conjunto de dados representa?
print("O primeiro conjunto de dados contém informações sobre diamantes, como qualidade do corte, peso em quilates, cor, claridade e profundidade.")
print("O segundo conjunto de dados contém informações de rastreamento de esquilos, como id do esquilo, localização de cada um e o horário em que a posição foi tomada pelo chip de rastreamento.")
print("O terceiro conjunto de dados contém informações sobre o mangá e anime One Piece, separados por arcos da história.")
# Out:
# O primeiro conjunto de dados contém informações sobre diamantes, como qualidade do corte, peso em quilates, cor, claridade e profundidade.
# O segundo conjunto de dados contém informações de rastreamento de esquilos, como id do esquilo, localização de cada um e o horário em que a posição foi tomada pelo chip de rastreamento.
# O terceiro conjunto de dados contém informações sobre o mangá e anime One Piece, separados por arcos da história.
