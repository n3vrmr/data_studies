# %% [markdown]
# # Spells for my Blood Wizard

# %%
import pandas as pd

file = "Spells - Blood Wizard.xlsx"
spells = pd.read_excel(file)
spells
# Out:
#                name  level       school      V      S  \
# 0     Spirit Shroud      3   Necromancy   True   True
# 1            Blight      4   Necromancy   True   True
# 2       Chill Touch      0   Necromancy   True   True
# 3        False Life      1   Necromancy   True   True
# 4          Firebolt      0    Evocation   True   True
# ..              ...    ...          ...    ...    ...
# 57     Storm Sphere      4    Evocation   True   True
# 58         Far Step      5  Conjuration   True  False
# 59        Soul Cage      6   Necromancy   True   True
# 60  Illusory Dragon      8     Illusion  False   True
# 61    Wall of Light      5    Evocation   True   True
#
#                                                  M    casting_time  \
# 0                                              NaN  1 bonus action
# 1                                              NaN        1 action
# 2                                              NaN        1 action
# ...

# %%
spells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           62 non-null     object
#  1   level          62 non-null     int64
#  2   school         62 non-null     object
#  3   V              62 non-null     bool
#  4   S              62 non-null     bool
#  5   M              30 non-null     object
#  6   casting_time   62 non-null     object
#  7   concentration  62 non-null     bool
#  8   duration       62 non-null     object
#  9   range          62 non-null     object
#  10  ritual         62 non-null     bool
# dtypes: bool(4), int64(1), object(6)
# memory usage: 3.8+ KB

# %% [markdown]
# ## Filtering by spell level

# %%
levels = spells["level"].value_counts()
levels
# Out:
# 3    9
# 1    9
# 4    7
# 5    7
# 0    6
# 2    6
# 6    6
# 7    5
# 8    4
# 9    3
# Name: level, dtype: int64

# %%
import matplotlib.pyplot as plt

labels_spells = ["3","1","4","5","0",
                 "2", "6", "7", "8",
                 "9"]

plt.pie(levels, labels=labels_spells, autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a7a91e520>,
# ...
#  [Text(0.9875850001117432, 0.484433553291149, '3'),
#   Text(0.2214284160296758, 1.077482926349457, '1'),
#   Text(-0.628394977978652, 0.9028398261326367, '4'),
#   Text(-1.0648848070200783, 0.2757178771458443, '5'),
#   Text(-1.0108536386373128, -0.43379133376971146, '0'),
#   Text(-0.581860526955042, -0.9335086111930628, '2'),
#   Text(0.055713929777725414, -1.098588165796775, '6'),
#   Text(0.628394893448684, -0.9028398849672168, '7'),
#   Text(0.9617811858585257, -0.53383232435716, '8'),
#   Text(1.0873151263246017, -0.16657075393272255, '9')],
#  [Text(0.5386827273336781, 0.26423648361335395, '14.52%'),
#   Text(0.12077913601618678, 0.5877179598269764, '14.52%'),
#   Text(-0.34276089707926466, 0.4924580869814381, '11.29%'),
#   Text(-0.580846258374588, 0.15039156935227868, '11.29%'),
#   Text(-0.5513747119839887, -0.23661345478347895, '9.68%'),
#   Text(-0.3173784692482047, -0.509186515196216, '9.68%'),
# ...

# %%
cantrips = spells[spells["level"] == 0]
cantrips
# Out:
#                 name  level         school     V     S    M casting_time  \
# 2        Chill Touch      0     Necromancy  True  True  NaN     1 action
# 4           Firebolt      0      Evocation  True  True  NaN     1 action
# 6     Shocking Grasp      0      Evocation  True  True  NaN     1 action
# 8       Ray of Frost      0      Evocation  True  True  NaN     1 action
# 39  Prestidigitation      0  Transmutation  True  True  NaN     1 action
# 40         Mage Hand      0    Conjuration  True  True  NaN     1 action
#
#     concentration        duration     range  ritual
# 2           False         1 round  120 feet   False
# 4           False   Instantaneous  120 feet   False
# 6           False   Instantaneous     Touch   False
# 8           False   Instantaneous   60 feet   False
# 39          False    Up to 1 hour   10 feet   False
# 40          False  Up to 1 minute   30 feet   False

# %%
first_level = spells[spells["level"] == 1]
first_level
# Out:
#                         name  level       school      V     S  \
# 3                 False Life      1   Necromancy   True  True
# 5                  Ice Knife      1  Conjuration  False  True
# 9   Tasha's Hideous Laughter      1  Enchantment   True  True
# 10                Mage Armor      1   Abjuration   True  True
# 11           Ray of Sickness      1   Necromancy   True  True
# 38             Frost Fingers      1    Evocation   True  True
# 43             Burning Hands      1    Evocation   True  True
# 44            Inflict Wounds      1   Necromancy   True  True
# 47                Witch Bolt      1    Evocation   True  True
#
#                                                     M casting_time  \
# 3      A small amount of alcohol or distilled spirits     1 action
# 5                   A drop of water or a piece of ice     1 action
# 9   Tiny tarts and a feather that is weaved in the...     1 action
# 10                           A piece of cured leather     1 action
# ...

# %%
second_level = spells[spells["level"] == 2]
second_level
# Out:
#                 name  level       school     V      S  \
# 13  Phantasmal Force      2     Illusion  True   True
# 14      Shadow Blade      2     Illusion  True   True
# 37        Misty Step      2  Conjuration  True  False
# 42      Invisibility      2     Illusion  True   True
# 49       Hold Person      2  Enchantment  True   True
# 56  See Invisibility      2   Divination  True   True
#
#                                                     M    casting_time  \
# 13                                    A bit of fleece        1 action
# 14                                                NaN  1 bonus action
# 37                                                NaN  1 bonus action
# 42                   An eyelash encased in gum arabic        1 action
# 49                    A small, straight piece of iron        1 action
# 56  A pinch of talc and a small sprinkling of powd...        1 action
#
#     concentration        duration    range  ritual
# ...

# %%
third_level = spells[spells["level"] == 3]
third_level
# Out:
#                  name  level       school      V     S  \
# 0       Spirit Shroud      3   Necromancy   True  True
# 7      Vampiric Touch      3   Necromancy   True  True
# 12       Counterspell      3   Abjuration  False  True
# 15           Fireball      3    Evocation   True  True
# 16  Life Transference      3   Necromancy   True  True
# 17     Lightning Bolt      3    Evocation   True  True
# 41        Feign Death      3   Necromancy   True  True
# 46       Dispel Magic      3   Abjuration   True  True
# 54    Hunger of Hadar      3  Conjuration   True  True
#
#                                                     M    casting_time  \
# 0                                                 NaN  1 bonus action
# 7                                                 NaN        1 action
# 12                                                NaN      1 reaction
# 15                A tiny ball of bat guano and sulfur        1 action
# ...

# %%
fourth_level = spells[spells["level"] == 4]
fourth_level
# Out:
#                        name  level       school     V     S  \
# 1                    Blight      4   Necromancy  True  True
# 18               Banishment      4   Abjuration  True  True
# 19  Evard's Black Tentacles      4  Conjuration  True  True
# 20     Greater Invisibility      4     Illusion  True  True
# 21        Phantasmal Killer      4     Illusion  True  True
# 22       Sickening Radiance      4    Evocation  True  True
# 57             Storm Sphere      4    Evocation  True  True
#
#                                                     M casting_time  \
# 1                                                 NaN     1 action
# 18                  An item distasteful to the target     1 action
# 19  A piece of tentacle from a giant octopus or a ...     1 action
# 20                                                NaN     1 action
# 21                                                NaN     1 action
# 22                                                NaN     1 action
# ...

# %%
fifth_level = spells[spells["level"] == 5]
fifth_level
# Out:
#                      name  level       school     V      S  \
# 23             Enervation      5   Necromancy  True   True
# 24  Negative Energy Flood      5   Necromancy  True  False
# 45                   Dawn      5    Evocation  True   True
# 50           Cone of Cold      5    Evocation  True   True
# 53           Hold Monster      5  Enchantment  True   True
# 58               Far Step      5  Conjuration  True  False
# 61          Wall of Light      5    Evocation  True   True
#
#                                            M    casting_time  concentration  \
# 23                                       NaN        1 action           True
# 24  A broken bone and a square of black silk        1 action          False
# 45  A sunburst pendant worth at least 100 gp        1 action           True
# 50             A small crystal or glass cone        1 action          False
# 53           A small, straight piece of iron        1 action           True
# ...

# %%
sixth_level = spells[spells["level"] == 6]
sixth_level
# Out:
#                name  level         school     V     S  \
# 25  Chain Lightning      6      Evocation  True  True
# 26  Circle of Death      6     Necromancy  True  True
# 27          Sunbeam      6      Evocation  True  True
# 30     Disintegrate      6  Transmutation  True  True
# 51          Eyebite      6     Necromancy  True  True
# 59        Soul Cage      6     Necromancy  True  True
#
#                                                     M casting_time  \
# 25  A bit of fur; a piece of amber, glass, or a cr...     1 action
# 26  The powder of a crushed black pearl worth at l...     1 action
# 27                                 A magnifying glass     1 action
# 30                    A lodestone and a pinch of dust     1 action
# 51                                                NaN     1 action
# 59                    A tiny silver cage worth 100 gp   1 reaction
#
#     concentration        duration         range  ritual
# ...

# %%
seventh_level = spells[spells["level"] == 7]
seventh_level
# Out:
#                name  level         school     V      S  \
# 28   Crown of Stars      7      Evocation  True   True
# 29  Finger of Death      7     Necromancy  True   True
# 31  Power Word Pain      7    Enchantment  True  False
# 36  Reverse Gravity      7  Transmutation  True   True
# 55  Prismatic Spray      7      Evocation  True   True
#
#                                 M casting_time  concentration        duration  \
# 28                            NaN     1 action          False          1 hour
# 29                            NaN     1 action          False   Instantaneous
# 31                            NaN     1 action          False   Instantaneous
# 36  A lodestone and iron fillings     1 action           True  Up to 1 minute
# 55                            NaN     1 action          False   Instantaneous
#
#            range  ritual
# 28      120 feet   False
# 29       60 feet   False
# 31       60 feet   False
# 36      100 feet   False
# 55  60-foot cone   False

# %%
eigth_level = spells[spells["level"] == 8]
eigth_level
# Out:
#                            name  level       school      V      S  \
# 32  Abi-Dalzim's Horrid Wilting      8   Necromancy   True   True
# 33                   Feeblemind      8  Enchantment   True   True
# 34           Maddening Darkness      8    Evocation   True  False
# 60              Illusory Dragon      8     Illusion  False   True
#
#                                                     M casting_time  \
# 32                                    A bit of sponge     1 action
# 33  A handful of clay, crystal, glass, or mineral ...     1 action
# 34       A drop of pitch mixed with a drop of mercury     1 action
# 60                                                NaN     1 action
#
#     concentration          duration     range  ritual
# 32          False     Instantaneous  150 feet   False
# 33          False     Instantaneous  150 feet   False
# 34           True  Up to 10 minutes  150 feet   False
# 60           True    Up to 1 minute  120 feet   False

# %%
ninth_level = spells[spells["level"] == 9]
ninth_level
# Out:
#                name  level       school     V      S                      M  \
# 35  Power Word Kill      9  Enchantment  True  False                    NaN
# 48     Meteor Swarm      9    Evocation  True   True                    NaN
# 52        Foresight      9   Divination  True   True  A hummingbird feather
#
#    casting_time  concentration       duration    range  ritual
# 35     1 action          False  Instantaneous  60 feet   False
# 48     1 action          False  Instantaneous   1 mile   False
# 52     1 minute          False        8 hours    Touch   False

# %% [markdown]
# ## Filtering by school of magic

# %%
schools = spells["school"].value_counts()
schools
# Out:
# Evocation        19
# Necromancy       16
# Conjuration       6
# Enchantment       6
# Illusion          6
# Abjuration        4
# Transmutation     3
# Divination        2
# Name: school, dtype: int64

# %%
labels_schools = ["Evocation", "Necromancy",
                  "Conjuration", "Enchantment",
                  "Illusion", "Abjuration",
                  "Transmutation", "Divination"]

plt.pie(schools, labels=labels_schools, autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a7a9c4b20>,
# ...
#  [Text(0.6283950202436337, 0.9028397967153438, 'Evocation'),
#   Text(-1.0108535980228326, 0.4337914284126578, 'Necromancy'),
#   Text(-0.834633950110179, -0.7165097133490093, 'Conjuration'),
#   Text(-0.2757178272949885, -1.0648848199273624, 'Enchantment'),
#   Text(0.38203571893599014, -1.0315273672845822, 'Illusion'),
#   Text(0.834633883025694, -0.7165097914930767, 'Abjuration'),
#   Text(1.0315273136314236, -0.38203586380383053, 'Transmutation'),
#   Text(1.0943562456479177, -0.11128525334200765, 'Divination')],
#  [Text(0.3427609201328911, 0.492458070935642, '30.65%'),
#   Text(-0.5513746898306359, 0.2366135064069042, '25.81%'),
#   Text(-0.45525488187827945, -0.39082348000855044, '9.68%'),
#   Text(-0.1503915421609028, -0.5808462654149249, '9.68%'),
#   Text(0.20838311941963097, -0.5626512912461357, '9.68%'),
#   Text(0.4552548452867421, -0.3908235226325873, '6.45%'),
#   Text(0.5626512619807764, -0.208383198438453, '4.84%'),
# ...

# %%
necromancy = spells[spells["school"] == "Necromancy"]
necromancy
# Out:
#                            name  level      school     V      S  \
# 0                 Spirit Shroud      3  Necromancy  True   True
# 1                        Blight      4  Necromancy  True   True
# 2                   Chill Touch      0  Necromancy  True   True
# 3                    False Life      1  Necromancy  True   True
# 7                Vampiric Touch      3  Necromancy  True   True
# 11              Ray of Sickness      1  Necromancy  True   True
# 16            Life Transference      3  Necromancy  True   True
# 23                   Enervation      5  Necromancy  True   True
# 24        Negative Energy Flood      5  Necromancy  True  False
# 26              Circle of Death      6  Necromancy  True   True
# 29              Finger of Death      7  Necromancy  True   True
# 32  Abi-Dalzim's Horrid Wilting      8  Necromancy  True   True
# 41                  Feign Death      3  Necromancy  True   True
# 44               Inflict Wounds      1  Necromancy  True   True
# ...

# %%
evocation = spells[spells["school"] == "Evocation"]
evocation
# Out:
#                   name  level     school     V      S  \
# 4             Firebolt      0  Evocation  True   True
# 6       Shocking Grasp      0  Evocation  True   True
# 8         Ray of Frost      0  Evocation  True   True
# 15            Fireball      3  Evocation  True   True
# 17      Lightning Bolt      3  Evocation  True   True
# 22  Sickening Radiance      4  Evocation  True   True
# 25     Chain Lightning      6  Evocation  True   True
# 27             Sunbeam      6  Evocation  True   True
# 28      Crown of Stars      7  Evocation  True   True
# 34  Maddening Darkness      8  Evocation  True  False
# 38       Frost Fingers      1  Evocation  True   True
# 43       Burning Hands      1  Evocation  True   True
# 45                Dawn      5  Evocation  True   True
# 47          Witch Bolt      1  Evocation  True   True
# 48        Meteor Swarm      9  Evocation  True   True
# 50        Cone of Cold      5  Evocation  True   True
# ...

# %%
illusion = spells[spells["school"] == "Illusion"]
illusion
# Out:
#                     name  level    school      V     S  \
# 13      Phantasmal Force      2  Illusion   True  True
# 14          Shadow Blade      2  Illusion   True  True
# 20  Greater Invisibility      4  Illusion   True  True
# 21     Phantasmal Killer      4  Illusion   True  True
# 42          Invisibility      2  Illusion   True  True
# 60       Illusory Dragon      8  Illusion  False  True
#
#                                    M    casting_time  concentration  \
# 13                   A bit of fleece        1 action           True
# 14                               NaN  1 bonus action           True
# 20                               NaN        1 action           True
# 21                               NaN        1 action           True
# 42  An eyelash encased in gum arabic        1 action           True
# 60                               NaN        1 action           True
#
#           duration     range  ritual
# 13  Up to 1 minute   60 feet   False
# ...

# %%
conjuration = spells[spells["school"] == "Conjuration"]
conjuration
# Out:
#                        name  level       school      V      S  \
# 5                 Ice Knife      1  Conjuration  False   True
# 19  Evard's Black Tentacles      4  Conjuration   True   True
# 37               Misty Step      2  Conjuration   True  False
# 40                Mage Hand      0  Conjuration   True   True
# 54          Hunger of Hadar      3  Conjuration   True   True
# 58                 Far Step      5  Conjuration   True  False
#
#                                                     M    casting_time  \
# 5                   A drop of water or a piece of ice        1 action
# 19  A piece of tentacle from a giant octopus or a ...        1 action
# 37                                                NaN  1 bonus action
# 40                                                NaN        1 action
# 54                         A pickled octopus tentacle        1 action
# 58                                                NaN  1 bonus action
#
# ...

# %%
enchantment = spells[spells["school"] == "Enchantment"]
enchantment
# Out:
#                         name  level       school     V      S  \
# 9   Tasha's Hideous Laughter      1  Enchantment  True   True
# 31           Power Word Pain      7  Enchantment  True  False
# 33                Feeblemind      8  Enchantment  True   True
# 35           Power Word Kill      9  Enchantment  True  False
# 49               Hold Person      2  Enchantment  True   True
# 53              Hold Monster      5  Enchantment  True   True
#
#                                                     M casting_time  \
# 9   Tiny tarts and a feather that is weaved in the...     1 action
# 31                                                NaN     1 action
# 33  A handful of clay, crystal, glass, or mineral ...     1 action
# 35                                                NaN     1 action
# 49                    A small, straight piece of iron     1 action
# 53                    A small, straight piece of iron     1 action
#
#     concentration        duration     range  ritual
# ...

# %%
abjuration = spells[spells["school"] == "Abjuration"]
abjuration
# Out:
#             name  level      school      V     S  \
# 10    Mage Armor      1  Abjuration   True  True
# 12  Counterspell      3  Abjuration  False  True
# 18    Banishment      4  Abjuration   True  True
# 46  Dispel Magic      3  Abjuration   True  True
#
#                                     M casting_time  concentration  \
# 10           A piece of cured leather     1 action          False
# 12                                NaN   1 reaction          False
# 18  An item distasteful to the target     1 action           True
# 46                                NaN     1 action          False
#
#           duration     range  ritual
# 10         8 hours     Touch   False
# 12   Instantaneous   60 feet   False
# 18  Up to 1 minute   60 feet   False
# 46   Instantaneous  120 feet   False

# %%
transmutation = spells[spells["school"] == "Transmutation"]
transmutation
# Out:
#                 name  level         school     V     S  \
# 30      Disintegrate      6  Transmutation  True  True
# 36   Reverse Gravity      7  Transmutation  True  True
# 39  Prestidigitation      0  Transmutation  True  True
#
#                                   M casting_time  concentration  \
# 30  A lodestone and a pinch of dust     1 action          False
# 36    A lodestone and iron fillings     1 action           True
# 39                              NaN     1 action          False
#
#           duration     range  ritual
# 30   Instantaneous   60 feet   False
# 36  Up to 1 minute  100 feet   False
# 39    Up to 1 hour   10 feet   False

# %%
divination = spells[spells["school"] == "Divination"]
divination
# Out:
#                 name  level      school     V     S  \
# 52         Foresight      9  Divination  True  True
# 56  See Invisibility      2  Divination  True  True
#
#                                                     M casting_time  \
# 52                              A hummingbird feather     1 minute
# 56  A pinch of talc and a small sprinkling of powd...     1 action
#
#     concentration duration  range  ritual
# 52          False  8 hours  Touch   False
# 56          False   1 hour   Self   False

# %% [markdown]
# ## Spells with material components

# %%
material_components = spells[spells["M"].notna()]
material_components
# Out:
#                            name  level         school      V      S  \
# 3                    False Life      1     Necromancy   True   True
# 5                     Ice Knife      1    Conjuration  False   True
# 9      Tasha's Hideous Laughter      1    Enchantment   True   True
# 10                   Mage Armor      1     Abjuration   True   True
# 13             Phantasmal Force      2       Illusion   True   True
# 15                     Fireball      3      Evocation   True   True
# 17               Lightning Bolt      3      Evocation   True   True
# 18                   Banishment      4     Abjuration   True   True
# 19      Evard's Black Tentacles      4    Conjuration   True   True
# 24        Negative Energy Flood      5     Necromancy   True  False
# 25              Chain Lightning      6      Evocation   True   True
# 26              Circle of Death      6     Necromancy   True   True
# 27                      Sunbeam      6      Evocation   True   True
# ...

# %%
spell_names = [i for i in spells["name"]]
spell_materials = [i for i in spells["M"].notna()]
# spells["M"].notna()
material_components.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 3 to 61
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           30 non-null     object
#  1   level          30 non-null     int64
#  2   school         30 non-null     object
#  3   V              30 non-null     bool
#  4   S              30 non-null     bool
#  5   M              30 non-null     object
#  6   casting_time   30 non-null     object
#  7   concentration  30 non-null     bool
#  8   duration       30 non-null     object
#  9   range          30 non-null     object
#  10  ritual         30 non-null     bool
# dtypes: bool(4), int64(1), object(6)
# memory usage: 2.0+ KB

# %%
d = {'No materials':32,'Materials':30}
ser = pd.Series(data=d, index=['No materials','Materials'])
ser
# Out:
# No materials    32
# Materials       30
# dtype: int64

# %%
plt.pie(ser, labels=['No materials','Materials'],
        autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a7aa4e850>,
# ...
#  [Text(-0.0557140326349728, 1.098588160580456, 'No materials'),
#   Text(0.055713929777725414, -1.098588165796775, 'Materials')],
#  [Text(-0.030389472346348798, 0.5992299057711576, '51.61%'),
#   Text(0.030389416242395675, -0.5992299086164228, '48.39%')])

# %%
def find_materials():
    for name in material_components["name"]:
        spell = material_components[material_components["name"] == name]
        print("Spell:",spell["name"].values[0],"\n",
              "Materials:",spell["M"].values[0],"\n")
    return

find_materials()
# Out:
# Spell: False Life
#  Materials: A small amount of alcohol or distilled spirits
#
# Spell: Ice Knife
#  Materials: A drop of water or a piece of ice
#
# Spell: Tasha's Hideous Laughter
#  Materials: Tiny tarts and a feather that is weaved in the air
#
# Spell: Mage Armor
#  Materials: A piece of cured leather
#
# Spell: Phantasmal Force
#  Materials: A bit of fleece
#
# Spell: Fireball
#  Materials: A tiny ball of bat guano and sulfur
#
# Spell: Lightning Bolt
#  Materials: A bit of fur and a rod of amber, crystal or glass
#
# Spell: Banishment
#  Materials: An item distasteful to the target
#
# Spell: Evard's Black Tentacles
#  Materials: A piece of tentacle from a giant octopus or a giant squid
#
# Spell: Negative Energy Flood
#  Materials: A broken bone and a square of black silk
#
# Spell: Chain Lightning
#  Materials: A bit of fur; a piece of amber, glass, or a crystal rod; and three silver pins
#
# Spell: Circle of Death
# ...

# %%
material_levels = material_components["level"].value_counts()
material_levels
# Out:
# 1    5
# 5    5
# 6    5
# 2    4
# 3    4
# 8    3
# 4    2
# 7    1
# 9    1
# Name: level, dtype: int64

# %%
material_lvl_labels = ["1", "5", "6",
                       "2", "3", "8",
                       "4", "7", "9"]

plt.pie(material_levels, labels=material_lvl_labels,
        autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a7bb24160>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, '1'),
#   Text(-5.149471629032507e-08, 1.0999999999999988, '5'),
#   Text(-0.9526279870751434, 0.5499999256737774, '6'),
#   Text(-1.004899951743044, -0.44741042342219545, '2'),
#   Text(-0.33991852729952715, -1.04616222202798, '3'),
#   Text(0.44741049398633764, -1.0048999203258508, '8'),
#   Text(0.8899188239641141, -0.6465635983832745, '4'),
#   Text(1.0461622419188967, -0.33991846608154164, '7'),
#   Text(1.0939741111904127, -0.11498105950610688, '9')],
#  [Text(0.5196152375893253, 0.30000000810831495, '16.67%'),
#   Text(-2.8088027067450036e-08, 0.5999999999999993, '16.67%'),
#   Text(-0.5196152656773508, 0.299999959458424, '16.67%'),
#   Text(-0.5481272464052966, -0.2440420491393793, '13.33%'),
#   Text(-0.18541010579974207, -0.5706339392879891, '13.33%'),
#   Text(0.24404208762891139, -0.5481272292686459, '10.00%'),
#   Text(0.48541026761678946, -0.35267105366360424, '6.67%'),
# ...

# %%
first_material = material_components[material_components["level"] == 1]
first_material
# Out:
#                         name  level       school      V     S  \
# 3                 False Life      1   Necromancy   True  True
# 5                  Ice Knife      1  Conjuration  False  True
# 9   Tasha's Hideous Laughter      1  Enchantment   True  True
# 10                Mage Armor      1   Abjuration   True  True
# 47                Witch Bolt      1    Evocation   True  True
#
#                                                     M casting_time  \
# 3      A small amount of alcohol or distilled spirits     1 action
# 5                   A drop of water or a piece of ice     1 action
# 9   Tiny tarts and a feather that is weaved in the...     1 action
# 10                           A piece of cured leather     1 action
# 47  A twig from a tree that has been struck by lig...     1 action
#
#     concentration        duration    range  ritual
# 3           False          1 hour     Self   False
# 5           False   Instantaneous  60 feet   False
# ...

# %%
second_material = material_components[material_components["level"] == 2]
second_material
# Out:
#                 name  level       school     V     S  \
# 13  Phantasmal Force      2     Illusion  True  True
# 42      Invisibility      2     Illusion  True  True
# 49       Hold Person      2  Enchantment  True  True
# 56  See Invisibility      2   Divination  True  True
#
#                                                     M casting_time  \
# 13                                    A bit of fleece     1 action
# 42                   An eyelash encased in gum arabic     1 action
# 49                    A small, straight piece of iron     1 action
# 56  A pinch of talc and a small sprinkling of powd...     1 action
#
#     concentration        duration    range  ritual
# 13           True  Up to 1 minute  60 feet   False
# 42           True    Up to 1 hour    Touch   False
# 49           True  Up to 1 minute  60 feet   False
# 56          False          1 hour     Self   False

# %%
third_material = material_components[material_components["level"] == 3]
third_material
# Out:
#                name  level       school     V     S  \
# 15         Fireball      3    Evocation  True  True
# 17   Lightning Bolt      3    Evocation  True  True
# 41      Feign Death      3   Necromancy  True  True
# 54  Hunger of Hadar      3  Conjuration  True  True
#
#                                                     M casting_time  \
# 15                A tiny ball of bat guano and sulfur     1 action
# 17  A bit of fur and a rod of amber, crystal or glass     1 action
# 41                          A pinch of graveyard dirt     1 action
# 54                         A pickled octopus tentacle     1 action
#
#     concentration        duration          range  ritual
# 15          False   Instantaneous       150 feet   False
# 17          False   Instantaneous  100-foot line   False
# 41          False          1 hour          Touch    True
# 54           True  Up to 1 minute       150 feet   False

# %%
fourth_material = material_components[material_components["level"] == 4]
fourth_material
# Out:
#                        name  level       school     V     S  \
# 18               Banishment      4   Abjuration  True  True
# 19  Evard's Black Tentacles      4  Conjuration  True  True
#
#                                                     M casting_time  \
# 18                  An item distasteful to the target     1 action
# 19  A piece of tentacle from a giant octopus or a ...     1 action
#
#     concentration        duration    range  ritual
# 18           True  Up to 1 minute  60 feet   False
# 19           True  Up to 1 minute  90 feet   False

# %%
fifth_material = material_components[material_components["level"] == 5]
fifth_material
# Out:
#                      name  level       school     V      S  \
# 24  Negative Energy Flood      5   Necromancy  True  False
# 45                   Dawn      5    Evocation  True   True
# 50           Cone of Cold      5    Evocation  True   True
# 53           Hold Monster      5  Enchantment  True   True
# 61          Wall of Light      5    Evocation  True   True
#
#                                            M casting_time  concentration  \
# 24  A broken bone and a square of black silk     1 action          False
# 45  A sunburst pendant worth at least 100 gp     1 action           True
# 50             A small crystal or glass cone     1 action          False
# 53           A small, straight piece of iron     1 action           True
# 61                             A hand mirror     1 action           True
#
#             duration         range  ritual
# 24     Instantaneous       60 feet   False
# 45    Up to 1 minute       60 feet   False
# ...

# %%
sixth_material = material_components[material_components["level"] == 6]
sixth_material
# Out:
#                name  level         school     V     S  \
# 25  Chain Lightning      6      Evocation  True  True
# 26  Circle of Death      6     Necromancy  True  True
# 27          Sunbeam      6      Evocation  True  True
# 30     Disintegrate      6  Transmutation  True  True
# 59        Soul Cage      6     Necromancy  True  True
#
#                                                     M casting_time  \
# 25  A bit of fur; a piece of amber, glass, or a cr...     1 action
# 26  The powder of a crushed black pearl worth at l...     1 action
# 27                                 A magnifying glass     1 action
# 30                    A lodestone and a pinch of dust     1 action
# 59                    A tiny silver cage worth 100 gp   1 reaction
#
#     concentration        duration         range  ritual
# 25          False   Instantaneous      150 feet   False
# 26          False   Instantaneous      150 feet   False
# 27           True  Up to 1 minute  60-foot line   False
# ...

# %%
seventh_material = material_components[material_components["level"] == 7]
seventh_material
# Out:
#                name  level         school     V     S  \
# 36  Reverse Gravity      7  Transmutation  True  True
#
#                                 M casting_time  concentration        duration  \
# 36  A lodestone and iron fillings     1 action           True  Up to 1 minute
#
#        range  ritual
# 36  100 feet   False

# %%
eigth_material = material_components[material_components["level"] == 8]
eigth_material
# Out:
#                            name  level       school     V      S  \
# 32  Abi-Dalzim's Horrid Wilting      8   Necromancy  True   True
# 33                   Feeblemind      8  Enchantment  True   True
# 34           Maddening Darkness      8    Evocation  True  False
#
#                                                     M casting_time  \
# 32                                    A bit of sponge     1 action
# 33  A handful of clay, crystal, glass, or mineral ...     1 action
# 34       A drop of pitch mixed with a drop of mercury     1 action
#
#     concentration          duration     range  ritual
# 32          False     Instantaneous  150 feet   False
# 33          False     Instantaneous  150 feet   False
# 34           True  Up to 10 minutes  150 feet   False

# %%
ninth_material = material_components[material_components["level"] == 9]
ninth_material
# Out:
#          name  level      school     V     S                      M  \
# 52  Foresight      9  Divination  True  True  A hummingbird feather
#
#    casting_time  concentration duration  range  ritual
# 52     1 minute          False  8 hours  Touch   False

# %%
material_schools = material_components["school"].value_counts()
material_schools
# Out:
# Evocation        9
# Necromancy       6
# Enchantment      4
# Conjuration      3
# Abjuration       2
# Illusion         2
# Transmutation    2
# Divination       2
# Name: school, dtype: int64

# %%
material_schools_labels = ["Evocation", "Necromancy",
                           "Enchantment", "Conjuration",
                           "Abjuration", "Illusion",
                           "Transmutation", "Divination"]

plt.pie(material_schools, labels=material_schools_labels,
        autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a7bb628e0>,
# ...
#  [Text(0.6465637441936395, 0.8899187180267095, 'Evocation'),
#   Text(-0.8899187482945419, 0.6465637025335369, 'Necromancy'),
#   Text(-1.004899951743044, -0.44741042342219545, 'Enchantment'),
#   Text(-0.4474101646869912, -1.0049000669393746, 'Conjuration'),
#   Text(0.1149814820102474, -1.0939740667834532, 'Abjuration'),
#   Text(0.5500001709502991, -0.952627845464661, 'Illusion'),
#   Text(0.8899188239641141, -0.6465635983832745, 'Transmutation'),
#   Text(1.075962411840778, -0.22870261980523152, 'Divination')],
#  [Text(0.3526711331965306, 0.48541020983275057, '30.00%'),
#   Text(-0.4854102263424773, 0.3526711104728383, '20.00%'),
#   Text(-0.5481272464052966, -0.2440420491393793, '13.33%'),
#   Text(-0.24404190801108608, -0.5481273092396588, '10.00%'),
#   Text(0.06271717200558947, -0.596713127336429, '6.67%'),
#   Text(0.3000000932456176, -0.5196151884352695, '6.67%'),
# ...

# %%
necromancy_material = material_components[material_components["school"] == "Necromancy"]
necromancy_material
# Out:
#                            name  level      school     V      S  \
# 3                    False Life      1  Necromancy  True   True
# 24        Negative Energy Flood      5  Necromancy  True  False
# 26              Circle of Death      6  Necromancy  True   True
# 32  Abi-Dalzim's Horrid Wilting      8  Necromancy  True   True
# 41                  Feign Death      3  Necromancy  True   True
# 59                    Soul Cage      6  Necromancy  True   True
#
#                                                     M casting_time  \
# 3      A small amount of alcohol or distilled spirits     1 action
# 24           A broken bone and a square of black silk     1 action
# 26  The powder of a crushed black pearl worth at l...     1 action
# 32                                    A bit of sponge     1 action
# 41                          A pinch of graveyard dirt     1 action
# 59                    A tiny silver cage worth 100 gp   1 reaction
#
# ...

# %%
evocation_material = material_components[material_components["school"] == "Evocation"]
evocation_material
# Out:
#                   name  level     school     V      S  \
# 15            Fireball      3  Evocation  True   True
# 17      Lightning Bolt      3  Evocation  True   True
# 25     Chain Lightning      6  Evocation  True   True
# 27             Sunbeam      6  Evocation  True   True
# 34  Maddening Darkness      8  Evocation  True  False
# 45                Dawn      5  Evocation  True   True
# 47          Witch Bolt      1  Evocation  True   True
# 50        Cone of Cold      5  Evocation  True   True
# 61       Wall of Light      5  Evocation  True   True
#
#                                                     M casting_time  \
# 15                A tiny ball of bat guano and sulfur     1 action
# 17  A bit of fur and a rod of amber, crystal or glass     1 action
# 25  A bit of fur; a piece of amber, glass, or a cr...     1 action
# 27                                 A magnifying glass     1 action
# 34       A drop of pitch mixed with a drop of mercury     1 action
# ...

# %%
conjuration_material = material_components[material_components["school"] == "Conjuration"]
conjuration_material
# Out:
#                        name  level       school      V     S  \
# 5                 Ice Knife      1  Conjuration  False  True
# 19  Evard's Black Tentacles      4  Conjuration   True  True
# 54          Hunger of Hadar      3  Conjuration   True  True
#
#                                                     M casting_time  \
# 5                   A drop of water or a piece of ice     1 action
# 19  A piece of tentacle from a giant octopus or a ...     1 action
# 54                         A pickled octopus tentacle     1 action
#
#     concentration        duration     range  ritual
# 5           False   Instantaneous   60 feet   False
# 19           True  Up to 1 minute   90 feet   False
# 54           True  Up to 1 minute  150 feet   False

# %%
enchantment_material = material_components[material_components["school"] == "Enchantment"]
enchantment_material
# Out:
#                         name  level       school     V     S  \
# 9   Tasha's Hideous Laughter      1  Enchantment  True  True
# 33                Feeblemind      8  Enchantment  True  True
# 49               Hold Person      2  Enchantment  True  True
# 53              Hold Monster      5  Enchantment  True  True
#
#                                                     M casting_time  \
# 9   Tiny tarts and a feather that is weaved in the...     1 action
# 33  A handful of clay, crystal, glass, or mineral ...     1 action
# 49                    A small, straight piece of iron     1 action
# 53                    A small, straight piece of iron     1 action
#
#     concentration        duration     range  ritual
# 9            True  Up to 1 minute   30 feet   False
# 33          False   Instantaneous  150 feet   False
# 49           True  Up to 1 minute   60 feet   False
# 53           True  Up to 1 minute   90 feet   False

# %%
abjuration_material = material_components[material_components["school"] == "Abjuration"]
abjuration_material
# Out:
#           name  level      school     V     S  \
# 10  Mage Armor      1  Abjuration  True  True
# 18  Banishment      4  Abjuration  True  True
#
#                                     M casting_time  concentration  \
# 10           A piece of cured leather     1 action          False
# 18  An item distasteful to the target     1 action           True
#
#           duration    range  ritual
# 10         8 hours    Touch   False
# 18  Up to 1 minute  60 feet   False

# %%
illusion_material = material_components[material_components["school"] == "Illusion"]
illusion_material
# Out:
#                 name  level    school     V     S  \
# 13  Phantasmal Force      2  Illusion  True  True
# 42      Invisibility      2  Illusion  True  True
#
#                                    M casting_time  concentration  \
# 13                   A bit of fleece     1 action           True
# 42  An eyelash encased in gum arabic     1 action           True
#
#           duration    range  ritual
# 13  Up to 1 minute  60 feet   False
# 42    Up to 1 hour    Touch   False

# %%
transmutation_material = material_components[material_components["school"] == "Transmutation"]
transmutation_material
# Out:
#                name  level         school     V     S  \
# 30     Disintegrate      6  Transmutation  True  True
# 36  Reverse Gravity      7  Transmutation  True  True
#
#                                   M casting_time  concentration  \
# 30  A lodestone and a pinch of dust     1 action          False
# 36    A lodestone and iron fillings     1 action           True
#
#           duration     range  ritual
# 30   Instantaneous   60 feet   False
# 36  Up to 1 minute  100 feet   False

# %%
divination_material = material_components[material_components["school"] == "Divination"]
divination_material
# Out:
#                 name  level      school     V     S  \
# 52         Foresight      9  Divination  True  True
# 56  See Invisibility      2  Divination  True  True
#
#                                                     M casting_time  \
# 52                              A hummingbird feather     1 minute
# 56  A pinch of talc and a small sprinkling of powd...     1 action
#
#     concentration duration  range  ritual
# 52          False  8 hours  Touch   False
# 56          False   1 hour   Self   False

# %% [markdown]
# ## Spells with no material components

# %%
no_materials = spells[spells["M"].isna()]
no_materials
# Out:
#                     name  level         school      V      S    M  \
# 0          Spirit Shroud      3     Necromancy   True   True  NaN
# 1                 Blight      4     Necromancy   True   True  NaN
# 2            Chill Touch      0     Necromancy   True   True  NaN
# 4               Firebolt      0      Evocation   True   True  NaN
# 6         Shocking Grasp      0      Evocation   True   True  NaN
# 7         Vampiric Touch      3     Necromancy   True   True  NaN
# 8           Ray of Frost      0      Evocation   True   True  NaN
# 11       Ray of Sickness      1     Necromancy   True   True  NaN
# 12          Counterspell      3     Abjuration  False   True  NaN
# 14          Shadow Blade      2       Illusion   True   True  NaN
# 16     Life Transference      3     Necromancy   True   True  NaN
# 20  Greater Invisibility      4       Illusion   True   True  NaN
# 21     Phantasmal Killer      4       Illusion   True   True  NaN
# ...

# %%
no_m_levels = no_materials["level"].value_counts()
no_m_levels
# Out:
# 0    6
# 3    5
# 4    5
# 1    4
# 7    4
# 2    2
# 5    2
# 9    2
# 6    1
# 8    1
# Name: level, dtype: int64

# %%
no_m_lvl_labels = ["0", "3", "4", "1",
                   "7", "2", "5", "9",
                   "6", "8"]

plt.pie(no_m_levels, labels=no_m_lvl_labels,
        autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a7bbd4640>,
# ...
#  [Text(0.9146165735327998, 0.6111272563215624, '0'),
#   Text(-0.10781885436251672, 1.0947031993394167, '3'),
#   Text(-0.9701133907831905, 0.5185364105085977, '4'),
#   Text(-1.0162674857624157, -0.4209517756015987, '1'),
#   Text(-0.4209517756015994, -1.0162674857624152, '7'),
#   Text(0.21459935421774115, -1.0788638084435536, '2'),
#   Text(0.6111272563215621, -0.9146165735328001, '5'),
#   Text(0.9146165735327998, -0.6111272563215624, '9'),
#   Text(1.0526343693054299, -0.31931314497990876, '6'),
#   Text(1.0947031993394167, -0.10781885436251656, '8')],
#  [Text(0.4988817673815271, 0.3333421398117613, '18.75%'),
#   Text(-0.05881028419773639, 0.5971108360033182, '15.62%'),
#   Text(-0.5291527586090129, 0.28283804209559865, '15.62%'),
#   Text(-0.5543277195067721, -0.2296100594190538, '12.50%'),
#   Text(-0.22961005941905419, -0.5543277195067718, '12.50%'),
#   Text(0.11705419320967697, -0.5884711682419382, '6.25%'),
# ...

# %%
cantrips_nom = no_materials[no_materials["level"] == 0]
cantrips_nom
# Out:
#                 name  level         school     V     S    M casting_time  \
# 2        Chill Touch      0     Necromancy  True  True  NaN     1 action
# 4           Firebolt      0      Evocation  True  True  NaN     1 action
# 6     Shocking Grasp      0      Evocation  True  True  NaN     1 action
# 8       Ray of Frost      0      Evocation  True  True  NaN     1 action
# 39  Prestidigitation      0  Transmutation  True  True  NaN     1 action
# 40         Mage Hand      0    Conjuration  True  True  NaN     1 action
#
#     concentration        duration     range  ritual
# 2           False         1 round  120 feet   False
# 4           False   Instantaneous  120 feet   False
# 6           False   Instantaneous     Touch   False
# 8           False   Instantaneous   60 feet   False
# 39          False    Up to 1 hour   10 feet   False
# 40          False  Up to 1 minute   30 feet   False

# %%
first_nom = no_materials[no_materials["level"] == 1]
first_nom
# Out:
#                name  level      school     V     S    M casting_time  \
# 11  Ray of Sickness      1  Necromancy  True  True  NaN     1 action
# 38    Frost Fingers      1   Evocation  True  True  NaN     1 action
# 43    Burning Hands      1   Evocation  True  True  NaN     1 action
# 44   Inflict Wounds      1  Necromancy  True  True  NaN     1 action
#
#     concentration       duration         range  ritual
# 11          False  Instantaneous       60 feet   False
# 38          False  Instantaneous  15-foot cone   False
# 43          False  Instantaneous  15-foot cone   False
# 44          False  Instantaneous         Touch   False

# %%
second_nom = no_materials[no_materials["level"] == 2]
second_nom
# Out:
#             name  level       school     V      S    M    casting_time  \
# 14  Shadow Blade      2     Illusion  True   True  NaN  1 bonus action
# 37    Misty Step      2  Conjuration  True  False  NaN  1 bonus action
#
#     concentration        duration range  ritual
# 14           True  Up to 1 minute  Self   False
# 37          False   Instantaneous  Self   False

# %%
third_nom = no_materials[no_materials["level"] == 3]
third_nom
# Out:
#                  name  level      school      V     S    M    casting_time  \
# 0       Spirit Shroud      3  Necromancy   True  True  NaN  1 bonus action
# 7      Vampiric Touch      3  Necromancy   True  True  NaN        1 action
# 12       Counterspell      3  Abjuration  False  True  NaN      1 reaction
# 16  Life Transference      3  Necromancy   True  True  NaN        1 action
# 46       Dispel Magic      3  Abjuration   True  True  NaN        1 action
#
#     concentration        duration     range  ritual
# 0            True  Up to 1 minute      Self   False
# 7            True  Up to 1 minute      Self   False
# 12          False   Instantaneous   60 feet   False
# 16          False   Instantaneous   30 feet   False
# 46          False   Instantaneous  120 feet   False

# %%
fourth_nom = no_materials[no_materials["level"] == 4]
fourth_nom
# Out:
#                     name  level      school     V     S    M casting_time  \
# 1                 Blight      4  Necromancy  True  True  NaN     1 action
# 20  Greater Invisibility      4    Illusion  True  True  NaN     1 action
# 21     Phantasmal Killer      4    Illusion  True  True  NaN     1 action
# 22    Sickening Radiance      4   Evocation  True  True  NaN     1 action
# 57          Storm Sphere      4   Evocation  True  True  NaN     1 action
#
#     concentration          duration     range  ritual
# 1           False     Instantaneous   30 feet   False
# 20           True    Up to 1 minute     Touch   False
# 21           True    Up to 1 minute  120 feet   False
# 22           True  Up to 10 minutes  120 feet   False
# 57           True    Up to 1 minute  150 feet   False

# %%
fifth_nom = no_materials[no_materials["level"] == 5]
fifth_nom
# Out:
#           name  level       school     V      S    M    casting_time  \
# 23  Enervation      5   Necromancy  True   True  NaN        1 action
# 58    Far Step      5  Conjuration  True  False  NaN  1 bonus action
#
#     concentration        duration    range  ritual
# 23           True  Up to 1 minute  60 feet   False
# 58           True  Up to 1 minute     Self   False

# %%
sixth_nom = no_materials[no_materials["level"] == 6]
sixth_nom
# Out:
#        name  level      school     V     S    M casting_time  concentration  \
# 51  Eyebite      6  Necromancy  True  True  NaN     1 action           True
#
#           duration    range  ritual
# 51  Up to 1 minute  60 feet   False

# %%
seventh_nom = no_materials[no_materials["level"] == 7]
seventh_nom
# Out:
#                name  level       school     V      S    M casting_time  \
# 28   Crown of Stars      7    Evocation  True   True  NaN     1 action
# 29  Finger of Death      7   Necromancy  True   True  NaN     1 action
# 31  Power Word Pain      7  Enchantment  True  False  NaN     1 action
# 55  Prismatic Spray      7    Evocation  True   True  NaN     1 action
#
#     concentration       duration         range  ritual
# 28          False         1 hour      120 feet   False
# 29          False  Instantaneous       60 feet   False
# 31          False  Instantaneous       60 feet   False
# 55          False  Instantaneous  60-foot cone   False

# %%
eigth_nom = no_materials[no_materials["level"] == 8]
eigth_nom
# Out:
#                name  level    school      V     S    M casting_time  \
# 60  Illusory Dragon      8  Illusion  False  True  NaN     1 action
#
#     concentration        duration     range  ritual
# 60           True  Up to 1 minute  120 feet   False

# %%
ninth_nom = no_materials[no_materials["level"] == 9]
ninth_nom
# Out:
#                name  level       school     V      S    M casting_time  \
# 35  Power Word Kill      9  Enchantment  True  False  NaN     1 action
# 48     Meteor Swarm      9    Evocation  True   True  NaN     1 action
#
#     concentration       duration    range  ritual
# 35          False  Instantaneous  60 feet   False
# 48          False  Instantaneous   1 mile   False

# %%
no_m_schools = no_materials["school"].value_counts()
no_m_schools
# Out:
# Necromancy       10
# Evocation        10
# Illusion          4
# Conjuration       3
# Abjuration        2
# Enchantment       2
# Transmutation     1
# Name: school, dtype: int64

# %%
no_m_schools_labels = ["Necromancy", "Evocation",
                       "Illusion", "Conjuration",
                       "Abjuration", "Enchantment",
                       "Transmutation"]

plt.pie(no_m_schools, labels=no_m_schools_labels,
        autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a7bcd8910>,
# ...
#  [Text(0.6111272563215626, 0.9146165735327998, 'Necromancy'),
#   Text(-1.0788638084435536, 0.21459935421774148, 'Evocation'),
#   Text(-0.4209517756015994, -1.0162674857624152, 'Illusion'),
#   Text(0.31931314497990826, -1.0526343693054299, 'Conjuration'),
#   Text(0.7778174593052022, -0.7778174593052025, 'Abjuration'),
#   Text(1.0162674857624152, -0.42095177560159946, 'Enchantment'),
#   Text(1.0947031993394167, -0.10781885436251656, 'Transmutation')],
#  [Text(0.33334213981176136, 0.4988817673815271, '31.25%'),
#   Text(-0.5884711682419382, 0.11705419320967717, '31.25%'),
#   Text(-0.22961005941905419, -0.5543277195067718, '12.50%'),
#   Text(0.17417080635267723, -0.5741642014393253, '9.38%'),
#   Text(0.4242640687119284, -0.4242640687119286, '6.25%'),
#   Text(0.5543277195067718, -0.2296100594190542, '6.25%'),
#   Text(0.5971108360033182, -0.058810284197736304, '3.12%')])

# %%
necromancy_nom = no_materials[no_materials["school"] == "Necromancy"]
necromancy_nom
# Out:
#                  name  level      school     V     S    M    casting_time  \
# 0       Spirit Shroud      3  Necromancy  True  True  NaN  1 bonus action
# 1              Blight      4  Necromancy  True  True  NaN        1 action
# 2         Chill Touch      0  Necromancy  True  True  NaN        1 action
# 7      Vampiric Touch      3  Necromancy  True  True  NaN        1 action
# 11    Ray of Sickness      1  Necromancy  True  True  NaN        1 action
# 16  Life Transference      3  Necromancy  True  True  NaN        1 action
# 23         Enervation      5  Necromancy  True  True  NaN        1 action
# 29    Finger of Death      7  Necromancy  True  True  NaN        1 action
# 44     Inflict Wounds      1  Necromancy  True  True  NaN        1 action
# 51            Eyebite      6  Necromancy  True  True  NaN        1 action
#
#     concentration        duration     range  ritual
# 0            True  Up to 1 minute      Self   False
# ...

# %%
evocation_nom = no_materials[no_materials["school"] == "Evocation"]
evocation_nom
# Out:
#                   name  level     school     V     S    M casting_time  \
# 4             Firebolt      0  Evocation  True  True  NaN     1 action
# 6       Shocking Grasp      0  Evocation  True  True  NaN     1 action
# 8         Ray of Frost      0  Evocation  True  True  NaN     1 action
# 22  Sickening Radiance      4  Evocation  True  True  NaN     1 action
# 28      Crown of Stars      7  Evocation  True  True  NaN     1 action
# 38       Frost Fingers      1  Evocation  True  True  NaN     1 action
# 43       Burning Hands      1  Evocation  True  True  NaN     1 action
# 48        Meteor Swarm      9  Evocation  True  True  NaN     1 action
# 55     Prismatic Spray      7  Evocation  True  True  NaN     1 action
# 57        Storm Sphere      4  Evocation  True  True  NaN     1 action
#
#     concentration          duration         range  ritual
# 4           False     Instantaneous      120 feet   False
# 6           False     Instantaneous         Touch   False
# ...

# %%
illusion_nom = no_materials[no_materials["school"] == "Illusion"]
illusion_nom
# Out:
#                     name  level    school      V     S    M    casting_time  \
# 14          Shadow Blade      2  Illusion   True  True  NaN  1 bonus action
# 20  Greater Invisibility      4  Illusion   True  True  NaN        1 action
# 21     Phantasmal Killer      4  Illusion   True  True  NaN        1 action
# 60       Illusory Dragon      8  Illusion  False  True  NaN        1 action
#
#     concentration        duration     range  ritual
# 14           True  Up to 1 minute      Self   False
# 20           True  Up to 1 minute     Touch   False
# 21           True  Up to 1 minute  120 feet   False
# 60           True  Up to 1 minute  120 feet   False

# %%
enchantment_nom = no_materials[no_materials["school"] == "Enchantment"]
enchantment_nom
# Out:
#                name  level       school     V      S    M casting_time  \
# 31  Power Word Pain      7  Enchantment  True  False  NaN     1 action
# 35  Power Word Kill      9  Enchantment  True  False  NaN     1 action
#
#     concentration       duration    range  ritual
# 31          False  Instantaneous  60 feet   False
# 35          False  Instantaneous  60 feet   False

# %%
conjuration_nom = no_materials[no_materials["school"] == "Conjuration"]
conjuration_nom
# Out:
#           name  level       school     V      S    M    casting_time  \
# 37  Misty Step      2  Conjuration  True  False  NaN  1 bonus action
# 40   Mage Hand      0  Conjuration  True   True  NaN        1 action
# 58    Far Step      5  Conjuration  True  False  NaN  1 bonus action
#
#     concentration        duration    range  ritual
# 37          False   Instantaneous     Self   False
# 40          False  Up to 1 minute  30 feet   False
# 58           True  Up to 1 minute     Self   False

# %%
abjuration_nom = no_materials[no_materials["school"] == "Abjuration"]
abjuration_nom
# Out:
#             name  level      school      V     S    M casting_time  \
# 12  Counterspell      3  Abjuration  False  True  NaN   1 reaction
# 46  Dispel Magic      3  Abjuration   True  True  NaN     1 action
#
#     concentration       duration     range  ritual
# 12          False  Instantaneous   60 feet   False
# 46          False  Instantaneous  120 feet   False

# %%
transmutation_nom = no_materials[no_materials["school"] == "Transmutation"]
transmutation_nom
# Out:
#                 name  level         school     V     S    M casting_time  \
# 39  Prestidigitation      0  Transmutation  True  True  NaN     1 action
#
#     concentration      duration    range  ritual
# 39          False  Up to 1 hour  10 feet   False

# %% [markdown]
# ## Spells that require concentration

# %%
concentration = spells[spells["concentration"] == True]
concentration
# Out:
#                         name  level         school      V      S  \
# 0              Spirit Shroud      3     Necromancy   True   True
# 7             Vampiric Touch      3     Necromancy   True   True
# 9   Tasha's Hideous Laughter      1    Enchantment   True   True
# 13          Phantasmal Force      2       Illusion   True   True
# 14              Shadow Blade      2       Illusion   True   True
# 18                Banishment      4     Abjuration   True   True
# 19   Evard's Black Tentacles      4    Conjuration   True   True
# 20      Greater Invisibility      4       Illusion   True   True
# 21         Phantasmal Killer      4       Illusion   True   True
# 22        Sickening Radiance      4      Evocation   True   True
# 23                Enervation      5     Necromancy   True   True
# 27                   Sunbeam      6      Evocation   True   True
# 34        Maddening Darkness      8      Evocation   True  False
# ...

# %%
concentration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           25 non-null     object
#  1   level          25 non-null     int64
#  2   school         25 non-null     object
#  3   V              25 non-null     bool
#  4   S              25 non-null     bool
#  5   M              14 non-null     object
#  6   casting_time   25 non-null     object
#  7   concentration  25 non-null     bool
#  8   duration       25 non-null     object
#  9   range          25 non-null     object
#  10  ritual         25 non-null     bool
# dtypes: bool(4), int64(1), object(6)
# memory usage: 1.7+ KB

# %%
d2 = {'No concentration':37, 'Concentration':25}
con_ser = pd.Series(data=d2, index=['No concentration','Concentration'])
con_ser
# Out:
# No concentration    37
# Concentration       25
# dtype: int64

# %%
plt.pie(con_ser, labels=['No concentration','Concentration'],
        autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a7bd11c40>,
# ...
#  [Text(-0.3292995240273152, 1.04955315419248, 'No concentration'),
#   Text(0.32929962229357157, -1.049553123361229, 'Concentration')],
#  [Text(-0.17961792219671738, 0.5724835386504437, '59.68%'),
#   Text(0.17961797579649355, -0.5724835218333976, '40.32%')])

# %%
con_levels = concentration["level"].value_counts()
con_levels
# Out:
# 4    6
# 5    5
# 2    4
# 3    3
# 1    2
# 6    2
# 8    2
# 7    1
# Name: level, dtype: int64

# %%
con_lvl_labels = ["4", "5", "2", "3",
                  "1", "6", "8", "7"]

plt.pie(con_levels, labels=con_lvl_labels,
        autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a7bd652b0>,
# ...
#  [Text(0.8018655028537539, 0.7530018030078657, '4'),
#   Text(-0.5894094518681141, 0.9287607324001856, '5'),
#   Text(-1.0913261750601648, -0.13786652831108218, '2'),
#   Text(-0.5894095170857548, -0.9287606910118115, '3'),
#   Text(0.06906950569907225, -1.0978294054098232, '1'),
#   Text(0.5894094083896854, -0.9287607599924328, '6'),
#   Text(0.9639373043865738, -0.5299291209321735, '8'),
#   Text(1.0913261589251626, -0.13786665603274467, '7')],
#  [Text(0.43738118337477483, 0.4107282561861085, '24.00%'),
#   Text(-0.3214960646553349, 0.5065967631273739, '20.00%'),
#   Text(-0.5952688227600899, -0.07519992453331754, '16.00%'),
#   Text(-0.3214961002285935, -0.5065967405518971, '12.00%'),
#   Text(0.037674275835857585, -0.5988160393144489, '8.00%'),
#   Text(0.3214960409398283, -0.5065967781776906, '8.00%'),
#   Text(0.5257839842108584, -0.2890522477811855, '8.00%'),
#   Text(0.5952688139591795, -0.0751999941996789, '4.00%')])

# %%
first_conc = concentration[concentration["level"] == 1]
first_conc
# Out:
#                         name  level       school     V     S  \
# 9   Tasha's Hideous Laughter      1  Enchantment  True  True
# 47                Witch Bolt      1    Evocation  True  True
#
#                                                     M casting_time  \
# 9   Tiny tarts and a feather that is weaved in the...     1 action
# 47  A twig from a tree that has been struck by lig...     1 action
#
#     concentration        duration    range  ritual
# 9            True  Up to 1 minute  30 feet   False
# 47           True  Up to 1 minute  30 feet   False

# %%
second_conc = concentration[concentration["level"] == 2]
second_conc
# Out:
#                 name  level       school     V     S  \
# 13  Phantasmal Force      2     Illusion  True  True
# 14      Shadow Blade      2     Illusion  True  True
# 42      Invisibility      2     Illusion  True  True
# 49       Hold Person      2  Enchantment  True  True
#
#                                    M    casting_time  concentration  \
# 13                   A bit of fleece        1 action           True
# 14                               NaN  1 bonus action           True
# 42  An eyelash encased in gum arabic        1 action           True
# 49   A small, straight piece of iron        1 action           True
#
#           duration    range  ritual
# 13  Up to 1 minute  60 feet   False
# 14  Up to 1 minute     Self   False
# 42    Up to 1 hour    Touch   False
# 49  Up to 1 minute  60 feet   False

# %%
third_conc = concentration[concentration["level"] == 3]
third_conc
# Out:
#                name  level       school     V     S  \
# 0     Spirit Shroud      3   Necromancy  True  True
# 7    Vampiric Touch      3   Necromancy  True  True
# 54  Hunger of Hadar      3  Conjuration  True  True
#
#                              M    casting_time  concentration        duration  \
# 0                          NaN  1 bonus action           True  Up to 1 minute
# 7                          NaN        1 action           True  Up to 1 minute
# 54  A pickled octopus tentacle        1 action           True  Up to 1 minute
#
#        range  ritual
# 0       Self   False
# 7       Self   False
# 54  150 feet   False

# %%
fourth_conc = concentration[concentration["level"] == 4]
fourth_conc
# Out:
#                        name  level       school     V     S  \
# 18               Banishment      4   Abjuration  True  True
# 19  Evard's Black Tentacles      4  Conjuration  True  True
# 20     Greater Invisibility      4     Illusion  True  True
# 21        Phantasmal Killer      4     Illusion  True  True
# 22       Sickening Radiance      4    Evocation  True  True
# 57             Storm Sphere      4    Evocation  True  True
#
#                                                     M casting_time  \
# 18                  An item distasteful to the target     1 action
# 19  A piece of tentacle from a giant octopus or a ...     1 action
# 20                                                NaN     1 action
# 21                                                NaN     1 action
# 22                                                NaN     1 action
# 57                                                NaN     1 action
#
#     concentration          duration     range  ritual
# ...

# %%
fifth_conc = concentration[concentration["level"] == 5]
fifth_conc
# Out:
#              name  level       school     V      S  \
# 23     Enervation      5   Necromancy  True   True
# 45           Dawn      5    Evocation  True   True
# 53   Hold Monster      5  Enchantment  True   True
# 58       Far Step      5  Conjuration  True  False
# 61  Wall of Light      5    Evocation  True   True
#
#                                            M    casting_time  concentration  \
# 23                                       NaN        1 action           True
# 45  A sunburst pendant worth at least 100 gp        1 action           True
# 53           A small, straight piece of iron        1 action           True
# 58                                       NaN  1 bonus action           True
# 61                             A hand mirror        1 action           True
#
#             duration     range  ritual
# 23    Up to 1 minute   60 feet   False
# 45    Up to 1 minute   60 feet   False
# 53    Up to 1 minute   90 feet   False
# ...

# %%
sixth_conc = concentration[concentration["level"] == 6]
sixth_conc
# Out:
#        name  level      school     V     S                   M casting_time  \
# 27  Sunbeam      6   Evocation  True  True  A magnifying glass     1 action
# 51  Eyebite      6  Necromancy  True  True                 NaN     1 action
#
#     concentration        duration         range  ritual
# 27           True  Up to 1 minute  60-foot line   False
# 51           True  Up to 1 minute       60 feet   False

# %%
seventh_conc = concentration[concentration["level"] == 7]
seventh_conc
# Out:
#                name  level         school     V     S  \
# 36  Reverse Gravity      7  Transmutation  True  True
#
#                                 M casting_time  concentration        duration  \
# 36  A lodestone and iron fillings     1 action           True  Up to 1 minute
#
#        range  ritual
# 36  100 feet   False

# %%
eigth_conc = concentration[concentration["level"] == 8]
eigth_conc
# Out:
#                   name  level     school      V      S  \
# 34  Maddening Darkness      8  Evocation   True  False
# 60     Illusory Dragon      8   Illusion  False   True
#
#                                                M casting_time  concentration  \
# 34  A drop of pitch mixed with a drop of mercury     1 action           True
# 60                                           NaN     1 action           True
#
#             duration     range  ritual
# 34  Up to 10 minutes  150 feet   False
# 60    Up to 1 minute  120 feet   False

# %%
con_schools = concentration["school"].value_counts()
con_schools
# Out:
# Evocation        7
# Illusion         6
# Necromancy       4
# Enchantment      3
# Conjuration      3
# Abjuration       1
# Transmutation    1
# Name: school, dtype: int64

# %%
con_schools_labels = ["Evocation", "Illusion",
                      "Necromancy", "Enchantment",
                      "Conjuration", "Abjuration",
                      "Transmutation"]

plt.pie(con_schools, labels=con_schools_labels,
        autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a7bde5070>,
# ...
#  [Text(0.7011663855493698, 0.8475645696792855, 'Evocation'),
#   Text(-0.8899186877588753, 0.6465637858537405, 'Illusion'),
#   Text(-0.8899187180267097, -0.6465637441936393, 'Necromancy'),
#   Text(-0.06906963418183067, -1.0978293973263735, 'Enchantment'),
#   Text(0.7011663260333261, -0.847564618915235, 'Conjuration'),
#   Text(1.0227540999762985, -0.40493709509215337, 'Abjuration'),
#   Text(1.0913261589251626, -0.13786665603274467, 'Transmutation')],
#  [Text(0.38245439211783805, 0.46230794709779205, '28.00%'),
#   Text(-0.4854101933230228, 0.3526711559202221, '24.00%'),
#   Text(-0.48541020983275074, -0.3526711331965305, '16.00%'),
#   Text(-0.03767434591736218, -0.5988160349052946, '12.00%'),
#   Text(0.3824543596545415, -0.4623079739537645, '12.00%'),
#   Text(0.5578658727143446, -0.22087477914117457, '4.00%'),
#   Text(0.5952688139591795, -0.0751999941996789, '4.00%')])

# %%
illusion_c = concentration[concentration["school"] == "Illusion"]
illusion_c
# Out:
#                     name  level    school      V     S  \
# 13      Phantasmal Force      2  Illusion   True  True
# 14          Shadow Blade      2  Illusion   True  True
# 20  Greater Invisibility      4  Illusion   True  True
# 21     Phantasmal Killer      4  Illusion   True  True
# 42          Invisibility      2  Illusion   True  True
# 60       Illusory Dragon      8  Illusion  False  True
#
#                                    M    casting_time  concentration  \
# 13                   A bit of fleece        1 action           True
# 14                               NaN  1 bonus action           True
# 20                               NaN        1 action           True
# 21                               NaN        1 action           True
# 42  An eyelash encased in gum arabic        1 action           True
# 60                               NaN        1 action           True
#
#           duration     range  ritual
# 13  Up to 1 minute   60 feet   False
# ...

# %%
necromancy_c = concentration[concentration["school"] == "Necromancy"]
necromancy_c
# Out:
#               name  level      school     V     S    M    casting_time  \
# 0    Spirit Shroud      3  Necromancy  True  True  NaN  1 bonus action
# 7   Vampiric Touch      3  Necromancy  True  True  NaN        1 action
# 23      Enervation      5  Necromancy  True  True  NaN        1 action
# 51         Eyebite      6  Necromancy  True  True  NaN        1 action
#
#     concentration        duration    range  ritual
# 0            True  Up to 1 minute     Self   False
# 7            True  Up to 1 minute     Self   False
# 23           True  Up to 1 minute  60 feet   False
# 51           True  Up to 1 minute  60 feet   False

# %%
evocation_c = concentration[concentration["school"] == "Evocation"]
evocation_c
# Out:
#                   name  level     school     V      S  \
# 22  Sickening Radiance      4  Evocation  True   True
# 27             Sunbeam      6  Evocation  True   True
# 34  Maddening Darkness      8  Evocation  True  False
# 45                Dawn      5  Evocation  True   True
# 47          Witch Bolt      1  Evocation  True   True
# 57        Storm Sphere      4  Evocation  True   True
# 61       Wall of Light      5  Evocation  True   True
#
#                                                     M casting_time  \
# 22                                                NaN     1 action
# 27                                 A magnifying glass     1 action
# 34       A drop of pitch mixed with a drop of mercury     1 action
# 45           A sunburst pendant worth at least 100 gp     1 action
# 47  A twig from a tree that has been struck by lig...     1 action
# 57                                                NaN     1 action
# ...

# %%
enchantment_c = concentration[concentration["school"] == "Enchantment"]
enchantment_c
# Out:
#                         name  level       school     V     S  \
# 9   Tasha's Hideous Laughter      1  Enchantment  True  True
# 49               Hold Person      2  Enchantment  True  True
# 53              Hold Monster      5  Enchantment  True  True
#
#                                                     M casting_time  \
# 9   Tiny tarts and a feather that is weaved in the...     1 action
# 49                    A small, straight piece of iron     1 action
# 53                    A small, straight piece of iron     1 action
#
#     concentration        duration    range  ritual
# 9            True  Up to 1 minute  30 feet   False
# 49           True  Up to 1 minute  60 feet   False
# 53           True  Up to 1 minute  90 feet   False

# %%
abjuration_c = concentration[concentration["school"] == "Abjuration"]
abjuration_c
# Out:
#           name  level      school     V     S  \
# 18  Banishment      4  Abjuration  True  True
#
#                                     M casting_time  concentration  \
# 18  An item distasteful to the target     1 action           True
#
#           duration    range  ritual
# 18  Up to 1 minute  60 feet   False

# %%
conjuration_c = concentration[concentration["school"] == "Conjuration"]
conjuration_c
# Out:
#                        name  level       school     V      S  \
# 19  Evard's Black Tentacles      4  Conjuration  True   True
# 54          Hunger of Hadar      3  Conjuration  True   True
# 58                 Far Step      5  Conjuration  True  False
#
#                                                     M    casting_time  \
# 19  A piece of tentacle from a giant octopus or a ...        1 action
# 54                         A pickled octopus tentacle        1 action
# 58                                                NaN  1 bonus action
#
#     concentration        duration     range  ritual
# 19           True  Up to 1 minute   90 feet   False
# 54           True  Up to 1 minute  150 feet   False
# 58           True  Up to 1 minute      Self   False

# %%
transmutation_c = concentration[concentration["school"] == "Transmutation"]
transmutation_c
# Out:
#                name  level         school     V     S  \
# 36  Reverse Gravity      7  Transmutation  True  True
#
#                                 M casting_time  concentration        duration  \
# 36  A lodestone and iron fillings     1 action           True  Up to 1 minute
#
#        range  ritual
# 36  100 feet   False

# %%
def starting_spells(cantrips:list):
    spellbook = pd.DataFrame({"name":[]})
    listed = []
    for spell in cantrips:
        to_add = spells[spells["name"] == spell]
        listed.append(to_add)
        if to_add["name"].values[0] not in spellbook["name"]:
            my_spells = pd.concat(listed, ignore_index=True)
    book = my_spells.to_csv("Spellbook.csv")
    permanent = pd.read_csv("Spellbook.csv")
    return permanent

# %% [markdown]
# # Cantrips at 1st level

# %%
spellbook = starting_spells(["Chill Touch","Ray of Frost", "Shocking Grasp"])
spellbook = spellbook.drop(labels='Unnamed: 0',axis=1)
spellbook
# Out:
#              name  level      school     V     S   M casting_time  \
# 0     Chill Touch      0  Necromancy  True  True NaN     1 action
# 1    Ray of Frost      0   Evocation  True  True NaN     1 action
# 2  Shocking Grasp      0   Evocation  True  True NaN     1 action
#
#    concentration       duration     range  ritual
# 0          False        1 round  120 feet   False
# 1          False  Instantaneous   60 feet   False
# 2          False  Instantaneous     Touch   False

# %% [markdown]
# # Spells at 1st level

# %%
def learn_spells(two_spells:list):
    listed = []
    for spell in two_spells:
        add = spells[spells["name"] == spell]
        listed.append(add)
        new_spells = pd.concat(listed, ignore_index=True)
        learn = pd.concat([spellbook,new_spells],ignore_index=True)
        learned = learn.to_csv("Spellbook.csv")
        ink = pd.read_csv("Spellbook.csv")
    ink = ink.drop(labels='Unnamed: 0',axis=1)
    ink = ink.sort_values("level", ignore_index=True)
    return ink

spellbook = learn_spells(["Mage Armor", "Inflict Wounds", "False Life",
                          "Ray of Sickness", "Ice Knife", "Frost Fingers"])
spellbook
# Out:
#               name  level       school      V     S  \
# 0      Chill Touch      0   Necromancy   True  True
# 1     Ray of Frost      0    Evocation   True  True
# 2   Shocking Grasp      0    Evocation   True  True
# 3       Mage Armor      1   Abjuration   True  True
# 4   Inflict Wounds      1   Necromancy   True  True
# 5       False Life      1   Necromancy   True  True
# 6  Ray of Sickness      1   Necromancy   True  True
# 7        Ice Knife      1  Conjuration  False  True
# 8    Frost Fingers      1    Evocation   True  True
#
#                                                 M casting_time  concentration  \
# 0                                             NaN     1 action          False
# 1                                             NaN     1 action          False
# 2                                             NaN     1 action          False
# 3                        A piece of cured leather     1 action          False
# ...

# %% [markdown]
# # Spells at 2nd level

# %%
spellbook = learn_spells(["Tasha's Hideous Laughter", "Witch Bolt"])
spellbook
# Out:
#                         name  level       school      V     S  \
# 0                Chill Touch      0   Necromancy   True  True
# 1               Ray of Frost      0    Evocation   True  True
# 2             Shocking Grasp      0    Evocation   True  True
# 3                 Mage Armor      1   Abjuration   True  True
# 4             Inflict Wounds      1   Necromancy   True  True
# 5                 False Life      1   Necromancy   True  True
# 6            Ray of Sickness      1   Necromancy   True  True
# 7                  Ice Knife      1  Conjuration  False  True
# 8              Frost Fingers      1    Evocation   True  True
# 9   Tasha's Hideous Laughter      1  Enchantment   True  True
# 10                Witch Bolt      1    Evocation   True  True
#
#                                                     M casting_time  \
# 0                                                 NaN     1 action
# 1                                                 NaN     1 action
# ...

# %% [markdown]
# # Spells at 3rd level

# %%
spellbook = learn_spells(["Phantasmal Force", "Shadow Blade"])
spellbook
# Out:
#                         name  level       school      V     S  \
# 0                Chill Touch      0   Necromancy   True  True
# 1               Ray of Frost      0    Evocation   True  True
# 2             Shocking Grasp      0    Evocation   True  True
# 3                 Mage Armor      1   Abjuration   True  True
# 4             Inflict Wounds      1   Necromancy   True  True
# 5                 False Life      1   Necromancy   True  True
# 6            Ray of Sickness      1   Necromancy   True  True
# 7                  Ice Knife      1  Conjuration  False  True
# 8              Frost Fingers      1    Evocation   True  True
# 9   Tasha's Hideous Laughter      1  Enchantment   True  True
# 10                Witch Bolt      1    Evocation   True  True
# 11          Phantasmal Force      2     Illusion   True  True
# 12              Shadow Blade      2     Illusion   True  True
#
#                                                     M    casting_time  \
# ...

# %% [markdown]
# # Spells at 4th level

# %%
spellbook = learn_spells(["Firebolt", "Invisibility", "Hold Person"])
spellbook
# Out:
#                         name  level       school      V     S  \
# 0                Chill Touch      0   Necromancy   True  True
# 1               Ray of Frost      0    Evocation   True  True
# 2             Shocking Grasp      0    Evocation   True  True
# 3                   Firebolt      0    Evocation   True  True
# 4                 Mage Armor      1   Abjuration   True  True
# 5             Inflict Wounds      1   Necromancy   True  True
# 6                 False Life      1   Necromancy   True  True
# 7            Ray of Sickness      1   Necromancy   True  True
# 8                  Ice Knife      1  Conjuration  False  True
# 9              Frost Fingers      1    Evocation   True  True
# 10  Tasha's Hideous Laughter      1  Enchantment   True  True
# 11                Witch Bolt      1    Evocation   True  True
# 12          Phantasmal Force      2     Illusion   True  True
# 13              Shadow Blade      2     Illusion   True  True
# ...

# %% [markdown]
# # Spells at 5th level

# %%
spellbook = learn_spells(["Spirit Shroud", "Vampiric Touch"])
spellbook
# Out:
#                         name  level       school      V     S  \
# 0                Chill Touch      0   Necromancy   True  True
# 1               Ray of Frost      0    Evocation   True  True
# 2             Shocking Grasp      0    Evocation   True  True
# 3                   Firebolt      0    Evocation   True  True
# 4                 Witch Bolt      1    Evocation   True  True
# 5   Tasha's Hideous Laughter      1  Enchantment   True  True
# 6              Frost Fingers      1    Evocation   True  True
# 7                  Ice Knife      1  Conjuration  False  True
# 8                 False Life      1   Necromancy   True  True
# 9             Inflict Wounds      1   Necromancy   True  True
# 10                Mage Armor      1   Abjuration   True  True
# 11           Ray of Sickness      1   Necromancy   True  True
# 12          Phantasmal Force      2     Illusion   True  True
# 13              Shadow Blade      2     Illusion   True  True
# ...

# %% [markdown]
# # Spells at 6th level

# %%
spellbook = learn_spells(["Life Transference", "Counterspell"])
spellbook
# Out:
#                         name  level       school      V     S  \
# 0                Chill Touch      0   Necromancy   True  True
# 1               Ray of Frost      0    Evocation   True  True
# 2             Shocking Grasp      0    Evocation   True  True
# 3                   Firebolt      0    Evocation   True  True
# 4            Ray of Sickness      1   Necromancy   True  True
# 5                 Mage Armor      1   Abjuration   True  True
# 6                 False Life      1   Necromancy   True  True
# 7             Inflict Wounds      1   Necromancy   True  True
# 8              Frost Fingers      1    Evocation   True  True
# 9   Tasha's Hideous Laughter      1  Enchantment   True  True
# 10                Witch Bolt      1    Evocation   True  True
# 11                 Ice Knife      1  Conjuration  False  True
# 12          Phantasmal Force      2     Illusion   True  True
# 13              Shadow Blade      2     Illusion   True  True
# ...

# %% [markdown]
# # Spells at 7th level

# %%
spellbook = learn_spells(["Blight", "Phantasmal Killer"])
spellbook
# Out:
#                         name  level       school      V     S  \
# 0                Chill Touch      0   Necromancy   True  True
# 1               Ray of Frost      0    Evocation   True  True
# 2             Shocking Grasp      0    Evocation   True  True
# 3                   Firebolt      0    Evocation   True  True
# 4                  Ice Knife      1  Conjuration  False  True
# 5   Tasha's Hideous Laughter      1  Enchantment   True  True
# 6              Frost Fingers      1    Evocation   True  True
# 7                 Witch Bolt      1    Evocation   True  True
# 8                 False Life      1   Necromancy   True  True
# 9                 Mage Armor      1   Abjuration   True  True
# 10           Ray of Sickness      1   Necromancy   True  True
# 11            Inflict Wounds      1   Necromancy   True  True
# 12          Phantasmal Force      2     Illusion   True  True
# 13              Shadow Blade      2     Illusion   True  True
# ...

# %% [markdown]
# # Spells at 8th level

# %%
spellbook = learn_spells(["Hunger of Hadar", "Evard's Black Tentacles"])
spellbook
# Out:
#                         name  level       school      V     S  \
# 0                Chill Touch      0   Necromancy   True  True
# 1               Ray of Frost      0    Evocation   True  True
# 2             Shocking Grasp      0    Evocation   True  True
# 3                   Firebolt      0    Evocation   True  True
# 4            Ray of Sickness      1   Necromancy   True  True
# 5                 Mage Armor      1   Abjuration   True  True
# 6                 False Life      1   Necromancy   True  True
# 7             Inflict Wounds      1   Necromancy   True  True
# 8              Frost Fingers      1    Evocation   True  True
# 9   Tasha's Hideous Laughter      1  Enchantment   True  True
# 10                 Ice Knife      1  Conjuration  False  True
# 11                Witch Bolt      1    Evocation   True  True
# 12          Phantasmal Force      2     Illusion   True  True
# 13              Shadow Blade      2     Illusion   True  True
# ...

# %% [markdown]
# # Spells at 9th level

# %%
spellbook = learn_spells(["Enervation", "Negative Energy Flood"])
spellbook
# Out:
#                         name  level       school      V      S  \
# 0                Chill Touch      0   Necromancy   True   True
# 1               Ray of Frost      0    Evocation   True   True
# 2             Shocking Grasp      0    Evocation   True   True
# 3                   Firebolt      0    Evocation   True   True
# 4            Ray of Sickness      1   Necromancy   True   True
# 5                 Mage Armor      1   Abjuration   True   True
# 6                 False Life      1   Necromancy   True   True
# 7             Inflict Wounds      1   Necromancy   True   True
# 8              Frost Fingers      1    Evocation   True   True
# 9   Tasha's Hideous Laughter      1  Enchantment   True   True
# 10                 Ice Knife      1  Conjuration  False   True
# 11                Witch Bolt      1    Evocation   True   True
# 12               Hold Person      2  Enchantment   True   True
# 13              Invisibility      2     Illusion   True   True
# ...

# %% [markdown]
# # Spells at 10th level

# %%
spellbook = learn_spells(["Prestidigitation", "Dawn", "Hold Monster"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5            Ray of Sickness      1     Necromancy   True   True
# 6                 Mage Armor      1     Abjuration   True   True
# 7                 False Life      1     Necromancy   True   True
# 8             Inflict Wounds      1     Necromancy   True   True
# 9              Frost Fingers      1      Evocation   True   True
# 10  Tasha's Hideous Laughter      1    Enchantment   True   True
# 11                 Ice Knife      1    Conjuration  False   True
# 12                Witch Bolt      1      Evocation   True   True
# ...

# %% [markdown]
# # Spells at 11th level

# %%
spellbook = learn_spells(["Circle of Death", "Disintegrate"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5            Ray of Sickness      1     Necromancy   True   True
# 6                 Mage Armor      1     Abjuration   True   True
# 7                 False Life      1     Necromancy   True   True
# 8             Inflict Wounds      1     Necromancy   True   True
# 9              Frost Fingers      1      Evocation   True   True
# 10  Tasha's Hideous Laughter      1    Enchantment   True   True
# 11                 Ice Knife      1    Conjuration  False   True
# 12                Witch Bolt      1      Evocation   True   True
# ...

# %% [markdown]
# # Spells at 12th level

# %%
spellbook = learn_spells(["Soul Cage", "Sickening Radiance"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5            Ray of Sickness      1     Necromancy   True   True
# 6                 Mage Armor      1     Abjuration   True   True
# 7                 False Life      1     Necromancy   True   True
# 8             Inflict Wounds      1     Necromancy   True   True
# 9              Frost Fingers      1      Evocation   True   True
# 10  Tasha's Hideous Laughter      1    Enchantment   True   True
# 11                 Ice Knife      1    Conjuration  False   True
# 12                Witch Bolt      1      Evocation   True   True
# ...

# %% [markdown]
# # Spells at 13th level

# %%
spellbook = learn_spells(["Crown of Stars", "Power Word Pain"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5                 Witch Bolt      1      Evocation   True   True
# 6                  Ice Knife      1    Conjuration  False   True
# 7   Tasha's Hideous Laughter      1    Enchantment   True   True
# 8              Frost Fingers      1      Evocation   True   True
# 9                 False Life      1     Necromancy   True   True
# 10                Mage Armor      1     Abjuration   True   True
# 11           Ray of Sickness      1     Necromancy   True   True
# 12            Inflict Wounds      1     Necromancy   True   True
# ...

# %% [markdown]
# # Spells at 14th level

# %%
spellbook = learn_spells(["Chain Lightning", "Wall of Light"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5             Inflict Wounds      1     Necromancy   True   True
# 6            Ray of Sickness      1     Necromancy   True   True
# 7                 Mage Armor      1     Abjuration   True   True
# 8                 False Life      1     Necromancy   True   True
# 9   Tasha's Hideous Laughter      1    Enchantment   True   True
# 10                 Ice Knife      1    Conjuration  False   True
# 11                Witch Bolt      1      Evocation   True   True
# 12             Frost Fingers      1      Evocation   True   True
# ...

# %% [markdown]
# # Spells at 15th level

# %%
spellbook = learn_spells(["Illusory Dragon", "Maddening Darkness"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5              Frost Fingers      1      Evocation   True   True
# 6                 Witch Bolt      1      Evocation   True   True
# 7                  Ice Knife      1    Conjuration  False   True
# 8   Tasha's Hideous Laughter      1    Enchantment   True   True
# 9                 Mage Armor      1     Abjuration   True   True
# 10           Ray of Sickness      1     Necromancy   True   True
# 11            Inflict Wounds      1     Necromancy   True   True
# 12                False Life      1     Necromancy   True   True
# ...

# %% [markdown]
# # Spells at 16th level

# %%
spellbook = learn_spells(["Feeblemind", "Fireball"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5                 False Life      1     Necromancy   True   True
# 6             Inflict Wounds      1     Necromancy   True   True
# 7            Ray of Sickness      1     Necromancy   True   True
# 8                 Mage Armor      1     Abjuration   True   True
# 9                  Ice Knife      1    Conjuration  False   True
# 10                Witch Bolt      1      Evocation   True   True
# 11             Frost Fingers      1      Evocation   True   True
# 12  Tasha's Hideous Laughter      1    Enchantment   True   True
# ...

# %% [markdown]
# # Spells at 17th level

# %%
spellbook = learn_spells(["Power Word Kill", "Foresight"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5   Tasha's Hideous Laughter      1    Enchantment   True   True
# 6              Frost Fingers      1      Evocation   True   True
# 7                 Witch Bolt      1      Evocation   True   True
# 8                  Ice Knife      1    Conjuration  False   True
# 9            Ray of Sickness      1     Necromancy   True   True
# 10            Inflict Wounds      1     Necromancy   True   True
# 11                False Life      1     Necromancy   True   True
# 12                Mage Armor      1     Abjuration   True   True
# ...

# %% [markdown]
# # Spells at 18th level

# %%
spellbook = learn_spells(["See Invisibility", "Far Step"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5                 Mage Armor      1     Abjuration   True   True
# 6                 False Life      1     Necromancy   True   True
# 7             Inflict Wounds      1     Necromancy   True   True
# 8            Ray of Sickness      1     Necromancy   True   True
# 9                 Witch Bolt      1      Evocation   True   True
# 10             Frost Fingers      1      Evocation   True   True
# 11  Tasha's Hideous Laughter      1    Enchantment   True   True
# 12                 Ice Knife      1    Conjuration  False   True
# ...

# %% [markdown]
# # Spells at 19th level

# %%
spellbook = learn_spells(["Eyebite", "Cone of Cold"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5                  Ice Knife      1    Conjuration  False   True
# 6   Tasha's Hideous Laughter      1    Enchantment   True   True
# 7              Frost Fingers      1      Evocation   True   True
# 8                 Witch Bolt      1      Evocation   True   True
# 9             Inflict Wounds      1     Necromancy   True   True
# 10                False Life      1     Necromancy   True   True
# 11                Mage Armor      1     Abjuration   True   True
# 12           Ray of Sickness      1     Necromancy   True   True
# ...

# %% [markdown]
# # Spells at 20th level

# %%
spellbook = learn_spells(["Meteor Swarm", "Greater Invisibility"])
spellbook
# Out:
#                         name  level         school      V      S  \
# 0                Chill Touch      0     Necromancy   True   True
# 1               Ray of Frost      0      Evocation   True   True
# 2             Shocking Grasp      0      Evocation   True   True
# 3                   Firebolt      0      Evocation   True   True
# 4           Prestidigitation      0  Transmutation   True   True
# 5                 Mage Armor      1     Abjuration   True   True
# 6                 False Life      1     Necromancy   True   True
# 7             Inflict Wounds      1     Necromancy   True   True
# 8            Ray of Sickness      1     Necromancy   True   True
# 9              Frost Fingers      1      Evocation   True   True
# 10  Tasha's Hideous Laughter      1    Enchantment   True   True
# 11                 Ice Knife      1    Conjuration  False   True
# 12                Witch Bolt      1      Evocation   True   True
# ...

# %%
def my_spell_components():
    my_materials = spellbook[spellbook["M"].notna()]
    for name in my_materials["name"]:
        spell = my_materials[my_materials["name"] == name]
        print("Spell:",spell["name"].values[0],"\n",
              "Materials:",spell["M"].values[0],"\n")
    return

my_spell_components()
# Out:
# Spell: Mage Armor
#  Materials: A piece of cured leather
#
# Spell: False Life
#  Materials: A small amount of alcohol or distilled spirits
#
# Spell: Tasha's Hideous Laughter
#  Materials: Tiny tarts and a feather that is weaved in the air
#
# Spell: Ice Knife
#  Materials: A drop of water or a piece of ice
#
# Spell: Witch Bolt
#  Materials: A twig from a tree that has been struck by lightning
#
# Spell: Invisibility
#  Materials: An eyelash encased in gum arabic
#
# Spell: Hold Person
#  Materials: A small, straight piece of iron
#
# Spell: See Invisibility
#  Materials: A pinch of talc and a small sprinkling of powdered silver
#
# Spell: Phantasmal Force
#  Materials: A bit of fleece
#
# Spell: Fireball
#  Materials: A tiny ball of bat guano and sulfur
#
# Spell: Hunger of Hadar
#  Materials: A pickled octopus tentacle
#
# Spell: Evard's Black Tentacles
#  Materials: A piece of tentacle from a giant octopus or a giant squid
#
# Spell: Negative Energy Flood
# ...

# %% [markdown]
# # Preparing spells

# %% [markdown]
# ## Cantrips

# %%
def known_cantrips():
    character_level = int(input("Enter your character level: ").strip().lower())
    if character_level < 4:
        three_cantrips = []
        cantrips = input("Enter 3 cantrips to prepare them: ").split(",")
        if len(cantrips) != 3:
            raise ValueError("Only 3 cantrips available at your level.")
        else:
            for cantrip in cantrips:
                cantrip_df = spellbook[spellbook["name"] == cantrip]
                three_cantrips.append(cantrip_df)
            known_cantrips = pd.concat(three_cantrips, ignore_index=True)
            return known_cantrips
    elif character_level >= 4 and character_level < 10:
        four_cantrips = []
        cantrips = input("Enter 4 cantrips to prepare them: ").split(",")
        if len(cantrips) != 4:
            raise ValueError("Only 4 cantrips available at your level.")
        else:
            for cantrip in cantrips:
                cantrip_df = spellbook[spellbook["name"] == cantrip]
                four_cantrips.append(cantrip_df)
            known_cantrips = pd.concat(four_cantrips, ignore_index=True)
            return known_cantrips
    else:
        five_cantrips = []
        cantrips = input("Enter 5 cantrips to prepare them: ").split(",")
        if len(cantrips) != 5:
            raise ValueError("Only 5 cantrips available at your level.")
        else:
            for cantrip in cantrips:
                cantrip_df = spellbook[spellbook["name"] == cantrip]
                five_cantrips.append(cantrip_df)
            known_cantrips = pd.concat(five_cantrips, ignore_index=True)
            return known_cantrips

my_cantrips = known_cantrips()
my_cantrips
# Out:
# Enter your character level: 2
# Enter 3 cantrips to prepare them: Chill Touch,Shocking Grasp,Ray of Frost
#              name  level      school     V     S    M casting_time  \
# 0     Chill Touch      0  Necromancy  True  True  NaN     1 action
# 1  Shocking Grasp      0   Evocation  True  True  NaN     1 action
# 2    Ray of Frost      0   Evocation  True  True  NaN     1 action
#
#    concentration       duration     range  ritual
# 0          False        1 round  120 feet   False
# 1          False  Instantaneous     Touch   False
# 2          False  Instantaneous   60 feet   False

# %% [markdown]
# ## Prepared spells

# %%
def prepare_spells():
    character_level = int(input("Enter your character level: ").strip().lower())
    character_int = int(input("Enter your Intelligence modifier: ").strip().lower())
    number_available = character_int + character_level
    prepare = input(f"Enter {number_available} spells to prepare them: ").split(",")
    if len(prepare) != number_available:
        raise ValueError(f"Number of spells must be equal to {number_available}.")
    else:
        my_spells = []
        for spell in prepare:
            spell_df = spellbook[spellbook["name"] == spell]
            my_spells.append(spell_df)
        prepared_spells = pd.concat(my_spells, ignore_index=True)
        prepared_spells = prepared_spells.sort_values("level", ignore_index=True)
        return prepared_spells
    
my_prepared_spells = prepare_spells()
my_prepared_spells
# Out:
# Enter your character level: 2
# Enter your Intelligence modifier: 4
# Enter 6 spells to prepare them: Mage Armor,Inflict Wounds,Ice Knife,Ray of Sickness,Frost Fingers,Tasha's Hideous Laughter
#                        name  level       school      V     S  \
# 0                Mage Armor      1   Abjuration   True  True
# 1            Inflict Wounds      1   Necromancy   True  True
# 2                 Ice Knife      1  Conjuration  False  True
# 3           Ray of Sickness      1   Necromancy   True  True
# 4             Frost Fingers      1    Evocation   True  True
# 5  Tasha's Hideous Laughter      1  Enchantment   True  True
#
#                                                    M casting_time  \
# 0                           A piece of cured leather     1 action
# 1                                                NaN     1 action
# 2                  A drop of water or a piece of ice     1 action
# 3                                                NaN     1 action
# ...

# %%
def required_spell_components():
    my_materials = my_prepared_spells[my_prepared_spells["M"].notna()]
    for name in my_materials["name"]:
        spell = my_materials[my_materials["name"] == name]
        print(f"Spell: {spell['name'].values[0]}\n",
              "Materials:",spell["M"].values[0],"\n")
    return

required_spell_components()
# Out:
# Spell: Mage Armor
#  Materials: A piece of cured leather
#
# Spell: Ice Knife
#  Materials: A drop of water or a piece of ice
#
# Spell: Tasha's Hideous Laughter
#  Materials: Tiny tarts and a feather that is weaved in the air
