# %%
from bs4 import BeautifulSoup
import requests

# %%
res = requests.get("https://crusoe.uol.com.br/edicoes/147/as-ligacoes-perigosas-do-governador-ostentacao/")
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.content,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js no-svg" lang="pt-BR" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="eyf4q1aznu9dv3mzpkry1hg8xk755b" name="facebook-domain-verification"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <base href="https://crusoe.uol.com.br/"/>
# <link href="https://crusoe.uol.com.br/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://crusoe.uol.com.br/favicon.ico" rel="icon" type="image/x-icon"/>
# <style media="print" type="text/css">
# 	body { display: none; }
# </style>
# <style>
#     #barrauol{
#         height:44px;
#     }
#
#     @media (min-width: 901px) {
#         body .ads_desktop {
#         display: block!important;
#         }
#         #Crusoe_EdSem_Desktop_Post_Halfpage{
#             width: 300px;
#             height: 600px;
#             margin: 0 auto;
#             margin-bottom: 2em;
#         }
# ...
